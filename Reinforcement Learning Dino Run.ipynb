# %%
import numpy as np
from PIL import Image
import cv2 #opencv
import io
import time
import pandas as pd
import numpy as np
from IPython.display import clear_output
from random import randint
import os

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
from keras.callbacks import TensorBoard
from collections import deque
import random
import pickle
from io import BytesIO
import base64
import json
# Out:
# C:\Users\baker\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#path variables
game_url = "chrome://dino"
chrome_driver_path = "./chromedriver"
loss_file_path = "./objects/loss_df.csv"
actions_file_path = "./objects/actions_df.csv"
q_value_file_path = "./objects/q_values.csv"
scores_file_path = "./objects/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('runner-canvas')[0].id = 'runner-canvas'"

#get image from canvas
getbase64Script = "canvasRunner = document.getElementById('runner-canvas'); \
return canvasRunner.toDataURL().substring(22)"

# %% [markdown]
# setting path

# %%
'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* get_crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        self._driver = webdriver.Chrome(executable_path = chrome_driver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.get('chrome://dino')
        self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def get_crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %% [markdown]
# 銜接browser-javascript與python的模組，運行chrome並且連接至小恐龍遊戲的環境。
# 這裡可以得到狀態:撞毀、遊戲中、分數。指令:重啟遊戲、跳躍、暫停、恢復遊戲、結束。

# %%
class DinoAgent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %% [markdown]
# 這裡為DinoAgent的模組，可知Agent是否撞毀，並有跳躍與蹲下兩種行為。我們在遊戲中只考慮跳躍與不跳躍兩種。

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        is_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            is_over = True
        return image, reward, is_over #return the Experience tuple

# %% [markdown]
# 為了確認Game的state，這裡使用OpenCV的截圖來獲取環境的狀態(OpenCV中影像處理的速度有經過特別優化)，這裡的get_state方法為輸入一個action，然後回傳下一狀態的影像、reward(如果撞毀=-1，沒撞毀=0.1)、is_over(是否撞毀)。OpenCV平均可以達到5FPS的擷取速度，這對於每個跳Action後的State轉換已經足夠表示。

# %%
def save_obj(obj, name ):
    with open('objects/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name ):
    with open('objects/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = process_img(screen)#processing image as required
    return image

def process_img(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:300, :500] #Crop Region of Interest(ROI)
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %% [markdown]
# 儲存object方法，後面會儲存的資料有:行為，格式為(S,a,r,St+1,是否結束)、時間(為了辨認FPS的更新狀態)、epsilon(隨機行為的機率隨時間遞減的參數)，螢幕截圖(單純擷取chrome中的遊戲影像)，影像處理(只保留有興趣的影像區域，在小恐龍的遊戲中其實只在乎仙人掌與螢幕左邊界的距離。size為80*80)

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %% [markdown]
# 使用DateFrame儲存loss,score,action,q_values。

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100. # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_obj(INITIAL_EPSILON,"epsilon")
    t = 0
    save_obj(t,"time")
    D = deque()
    save_obj(D,"D")

# %%
'''Call only once to init file structure
'''
#init_cache()
# Out:
# 'Call only once to init file structure\n'

# %% [markdown]
# 如果想要執行訓練，第一次需要執行init_cache()，他會創建所需的檔案。在這之前須建立object空白資料夾以存放。

# %%
def buildmodel():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model.h5')
    print("We finish building the model")
    return model

# %% [markdown]
# 模型輸入為80*80*4，即每四張影像為一組State，再經過幾次捲積與池化，再展平成512的特徵向量，最後輸出(0,1)代表不跳與跳，這裡的類神經網路用來替代傳統的Q-table，由於影像為格式的state很難窮舉到Q-table中，因此使用類神經網路，好處是可以舉一反三，State的pixel值即使不盡相同，但是仍可以訓練出其特性。這個方法即為DQN，為一種off-policy learning。

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate wherther the model is to be trained(weight updates), else just play
'''
def trainNetwork(model,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_obj("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        #epsilon = load_obj("epsilon") 
        epsilon = 0
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_obj("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[0] = 1
            else: # predict the output
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1        # o=> do nothing, 1=> jump
                
        #We reduced the epsilon (exploration parameter) gradually
        #if epsilon >= FINAL_EPSILON and t > OBSERVE:
            #epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 
            #epsilon=0
        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    

                targets[i] = model.predict(state_t)  # predicted q values
                Q_sa = model.predict(state_t1)      #predict q values for next step
                
                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            loss += model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = np.max(Q_sa)
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        # save progress every 1000 iterations
        if t % 20000 == 0:
            print("Now we save model")
            game_state._game.pause() #pause game while saving to filesystem
            model.save_weights("model.h5", overwrite=True)
            save_obj(D,"D") #saving episodes
            save_obj(t,"time") #caching time steps
            save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects/loss_df.csv",index=False)
            scores_df.to_csv("./objects/scores_df.csv",index=False)
            actions_df.to_csv("./objects/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state,             "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t,             "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %% [markdown]
# 這裡寫下訓練的過程，我們先觀察100次，然後到累積10萬筆之前都是EXPLORE狀態，但仍會訓練神經網路，這是因為epsilon(隨機動作的機率)在10萬次以後才會收斂到最低值，後面的狀態我們稱為訓練狀態。
# 訓練方式是這樣的:使用當前state預測下一步的action並且概率地(取決於epsilon)執行，這時候觀察St+1與reward並記錄下來，然後從replay buffer中隨機取出32筆資料出來訓練，得到32組(S,A,r,St+1,terminal)，如果恐龍在此State,S採取Action,A，陣亡了，那麼reward就不更新，但如果沒有陣亡，則reward=reward+GAMMA*max(Q_sa)，意思是此State的Action會讓你的恐龍活著，所以是好棒棒的，所以多給一點reward，然後在拿其S,A,r進行supervised learning，Ptrue為更新過的reward，在進行反向傳播法更新參數，如此一來網路就會更像理想的Q_table，

# %%
#main function
def playGame(observe=False):
    game = Game()
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)    
    model = buildmodel()
    try:
        trainNetwork(model,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
playGame(observe=False);
# Out:
# Now we build the model
# We finish building the model
# fps: 0.215493308272021
# TIMESTEP 320001 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.396174 / Loss  3.8856799602508545
# fps: 0.9123853754833237
# TIMESTEP 320002 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.204363 / Loss  0.020749880000948906
# fps: 5.637641770903059
# TIMESTEP 320003 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.164232 / Loss  2.414555788040161
# fps: 7.135900642252563
# TIMESTEP 320004 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.083686 / Loss  0.04089697450399399
# fps: 6.101222919966892
# TIMESTEP 320005 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.904004 / Loss  0.44432443380355835
# fps: 6.535464087158136
# TIMESTEP 320006 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.267053 / Loss  0.019154895097017288
# fps: 5.99106690111171
# TIMESTEP 320007 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.038898 / Loss  0.029847338795661926
# fps: 6.941189515161445
# TIMESTEP 320008 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.716545 / Loss  0.026824746280908585
# fps: 6.071257559571888
# TIMESTEP 320009 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.839025 / Loss  0.010722738690674305
# fps: 4.969878368851051
# TIMESTEP 320010 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.918236 / Loss  0.047890350222587585
# fps: 5.336149218146681
# TIMESTEP 320011 / STATE train / EPSILON 0 / ACTION 1 / REWARD -1 / Q_MAX  10.035091 / Loss  0.010316732339560986
# fps: 5.542984087211753
# TIMESTEP 320012 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.20007 / Loss  0.03122871182858944
# fps: 5.999310572696676
# TIMESTEP 320013 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.949982 / Loss  0.6743863224983215
# fps: 6.149951759955191
# TIMESTEP 320014 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.977409 / Loss  0.033006519079208374
# fps: 5.939661715891196
# TIMESTEP 320015 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.166352 / Loss  0.021744776517152786
# fps: 6.045172643901146
# TIMESTEP 320016 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.759848 / Loss  0.026783211156725883
# fps: 5.993823693751241
# TIMESTEP 320017 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.945835 / Loss  0.038495369255542755
# fps: 5.647532783342467
# TIMESTEP 320018 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.029415 / Loss  0.028620513156056404
# fps: 5.744724796401658
# TIMESTEP 320019 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.090789 / Loss  0.08000215888023376
# fps: 6.032938550185981
# TIMESTEP 320020 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.497094 / Loss  0.05478217452764511
# fps: 5.958656117834752
# TIMESTEP 320021 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.442828 / Loss  0.14136171340942383
# fps: 6.0033464011874145
# TIMESTEP 320022 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.980062 / Loss  0.011123741045594215
# fps: 6.069245740332091
# TIMESTEP 320023 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.381126 / Loss  0.019016679376363754
# fps: 5.462883995717535
# TIMESTEP 320024 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.236413 / Loss  0.021456167101860046
# fps: 6.039836414953056
# TIMESTEP 320025 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.152483 / Loss  0.009303966537117958
# fps: 6.272165953609673
# TIMESTEP 320026 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.538538 / Loss  0.020013632252812386
# fps: 6.000434907010014
# TIMESTEP 320027 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.271299 / Loss  0.011988973245024681
# fps: 5.968534414061611
# TIMESTEP 320028 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.101314 / Loss  0.03934985399246216
# fps: 6.05619697240977
# TIMESTEP 320029 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.630488 / Loss  0.12831415235996246
# fps: 3.831292835161302
# TIMESTEP 320030 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.226226 / Loss  0.0253307968378067
# fps: 6.011675622372591
# TIMESTEP 320031 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.749356 / Loss  0.13169750571250916
# fps: 6.087029210978498
# TIMESTEP 320032 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.600832 / Loss  0.0369478203356266
# fps: 5.953192618803288
# TIMESTEP 320033 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.952454 / Loss  0.06738343834877014
# fps: 6.021791159204102
# TIMESTEP 320034 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.452389 / Loss  0.03730633854866028
# fps: 7.119415550908449
# TIMESTEP 320035 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.446311 / Loss  0.10281351208686829
# fps: 7.173281889203574
# TIMESTEP 320036 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.5595045 / Loss  0.1128029152750969
# fps: 7.149767743145227
# TIMESTEP 320037 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.476929 / Loss  0.03709782287478447
# fps: 5.96425686821
# TIMESTEP 320038 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.658831 / Loss  0.023439843207597733
# fps: 5.9842713814475355
# TIMESTEP 320039 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.489235 / Loss  0.05087633058428764
# fps: 6.231925531361668
# TIMESTEP 320040 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.082894 / Loss  0.013109253719449043
# fps: 7.016197643705368
# TIMESTEP 320041 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  11.249593 / Loss  0.33385971188545227
# fps: 7.134334857391683
# TIMESTEP 320042 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.933043 / Loss  0.020982056856155396
# fps: 5.946086485612903
# TIMESTEP 320043 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.708162 / Loss  0.015450694598257542
# fps: 6.020373626531359
# TIMESTEP 320044 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.11503 / Loss  0.012748915702104568
# fps: 6.115786158386506
# TIMESTEP 320045 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.272268 / Loss  0.08950228244066238
# fps: 5.916403358310012
# TIMESTEP 320046 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.573166 / Loss  0.029591286554932594
# fps: 7.089427816127702
# TIMESTEP 320047 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.792952 / Loss  0.3468695282936096
# fps: 5.918482133659951
# TIMESTEP 320048 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.809177 / Loss  0.03481520712375641
# fps: 5.887742339400797
# TIMESTEP 320049 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.85956 / Loss  1.6081531047821045
# fps: 6.126318034228357
# TIMESTEP 320050 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.676119 / Loss  0.04797406867146492
# fps: 7.191053154044374
# TIMESTEP 320051 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.747999 / Loss  0.024103224277496338
# fps: 7.115212626636176
# TIMESTEP 320052 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.850742 / Loss  0.011447804048657417
# fps: 5.989740777553095
# TIMESTEP 320053 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.651088 / Loss  2.8919689655303955
# fps: 6.0422552660618125
# TIMESTEP 320054 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.484468 / Loss  0.670940637588501
# fps: 5.63605848498571
# TIMESTEP 320055 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.694277 / Loss  0.09850692003965378
# fps: 6.755222274834192
# TIMESTEP 320056 / STATE train / EPSILON 0 / ACTION 0 / REWARD -1 / Q_MAX  10.493909 / Loss  0.04526437073945999
# fps: 7.081312699854467
# TIMESTEP 320057 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.158355 / Loss  0.09715992212295532
# fps: 6.150222295212735
# TIMESTEP 320058 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.284057 / Loss  0.0212031751871109
# fps: 6.097205141400133
# TIMESTEP 320059 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.245265 / Loss  0.015088465064764023
# fps: 6.099776619508563
# TIMESTEP 320060 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.9807005 / Loss  0.200607568025589
# fps: 5.446228558814745
# TIMESTEP 320061 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.288724 / Loss  0.023942384868860245
# fps: 3.8435986818713324
# TIMESTEP 320062 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.0591345 / Loss  0.022996719926595688
# fps: 5.827024654002073
# TIMESTEP 320063 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.033935 / Loss  0.029853232204914093
# fps: 7.053008073208751
# TIMESTEP 320064 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.934183 / Loss  0.013776391744613647
# fps: 7.138147347640362
# TIMESTEP 320065 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.105944 / Loss  0.1146804541349411
# fps: 6.234380248822034
# TIMESTEP 320066 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.899192 / Loss  0.5389309525489807
# fps: 5.958063613415893
# TIMESTEP 320067 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.770458 / Loss  0.9702993035316467
# fps: 6.063893246203112
# TIMESTEP 320068 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.012741 / Loss  0.23464900255203247
# fps: 6.051880217817268
# TIMESTEP 320069 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.0562105 / Loss  0.014242097735404968
# fps: 4.34792488192829
# TIMESTEP 320070 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.362859 / Loss  0.5860916972160339
# fps: 6.187548498071879
# TIMESTEP 320071 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.505553 / Loss  0.019499845802783966
# fps: 7.037399203358378
# TIMESTEP 320072 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.804548 / Loss  3.8736000061035156
# fps: 7.332353193118506
# TIMESTEP 320073 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.66609 / Loss  0.033238984644412994
# fps: 6.911815645542169
# TIMESTEP 320074 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.772351 / Loss  0.02078213542699814
# fps: 7.071653895113089
# TIMESTEP 320075 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.677191 / Loss  0.02147797867655754
# fps: 6.988689607368751
# TIMESTEP 320076 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.7632065 / Loss  0.012961657717823982
# fps: 6.767287682460701
# TIMESTEP 320077 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.987304 / Loss  0.04395637661218643
# fps: 7.18105598728939
# TIMESTEP 320078 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.6961155 / Loss  0.02770940214395523
# fps: 6.755581326053168
# TIMESTEP 320079 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.529914 / Loss  0.2574043869972229
# fps: 6.912635824108089
# TIMESTEP 320080 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.3833065 / Loss  0.01211907621473074
# fps: 7.452367118857884
# TIMESTEP 320081 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.630553 / Loss  0.030373845249414444
# fps: 6.618084965381436
# TIMESTEP 320082 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.46771 / Loss  0.015070928260684013
# fps: 7.3809464313053335
# TIMESTEP 320083 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.623942 / Loss  0.046960264444351196
# fps: 6.926196928188437
# TIMESTEP 320084 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.595712 / Loss  0.016559867188334465
# fps: 7.191817628449687
# TIMESTEP 320085 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.27569 / Loss  0.010255509987473488
# fps: 6.98434879914209
# TIMESTEP 320086 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.295093 / Loss  0.014385702088475227
# fps: 6.815573610659733
# TIMESTEP 320087 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.31657 / Loss  0.017080629244446754
# fps: 6.996873821844545
# TIMESTEP 320088 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.404705 / Loss  0.027872616425156593
# fps: 7.084254974158025
# TIMESTEP 320089 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.398835 / Loss  0.40435099601745605
# fps: 6.9424763014544375
# TIMESTEP 320090 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.437371 / Loss  0.015875376760959625
# fps: 6.937940206369738
# TIMESTEP 320091 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.246995 / Loss  0.02861497551202774
# fps: 6.973711644456268
# TIMESTEP 320092 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.457064 / Loss  0.049797385931015015
# fps: 7.117398010870469
# TIMESTEP 320093 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.325115 / Loss  0.09421864151954651
# fps: 6.681509140610563
# TIMESTEP 320094 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.60056 / Loss  0.024698425084352493
# fps: 7.122643576075494
# TIMESTEP 320095 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.239874 / Loss  0.009364847093820572
# fps: 7.003451379299405
# TIMESTEP 320096 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.340267 / Loss  0.020134642720222473
# fps: 3.633945907168682
# TIMESTEP 320097 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.3735 / Loss  0.010795550420880318
# fps: 5.966165729038498
# TIMESTEP 320098 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.229982 / Loss  0.014562753960490227
# fps: 6.237792273074738
# TIMESTEP 320099 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.516336 / Loss  0.02770538628101349
# fps: 7.160582433772827
# TIMESTEP 320100 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.407583 / Loss  0.0070975786074995995
# fps: 6.252838469611678
# TIMESTEP 320101 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.449386 / Loss  0.021838797256350517
# fps: 6.882610279518088
# TIMESTEP 320102 / STATE train / EPSILON 0 / ACTION 0 / REWARD -1 / Q_MAX  9.482734 / Loss  0.01812710613012314
# fps: 7.105954744753088
# TIMESTEP 320103 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.469882 / Loss  0.02361874282360077
# fps: 6.130885054967864
# TIMESTEP 320104 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.756044 / Loss  0.0068657286465168
# fps: 6.0248445777456014
# TIMESTEP 320105 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.703989 / Loss  0.3195139467716217
# fps: 6.086932039990305
# TIMESTEP 320106 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.661942 / Loss  0.10675888508558273
# fps: 6.130445967119572
# TIMESTEP 320107 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.578791 / Loss  0.01635439693927765
# fps: 5.995580116815282
# TIMESTEP 320108 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.8105545 / Loss  0.013598309829831123
# fps: 6.0124770642201835
# TIMESTEP 320109 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.561803 / Loss  0.006927943788468838
# fps: 6.189100653394167
# TIMESTEP 320110 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.604405 / Loss  0.015595167875289917
# fps: 5.9784284742998945
# TIMESTEP 320111 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.648734 / Loss  0.005748864728957415
# fps: 5.960679985561249
# TIMESTEP 320112 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.891858 / Loss  0.005628191865980625
# fps: 6.081028103506269
# TIMESTEP 320113 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.8987055 / Loss  0.01785624399781227
# fps: 6.014347926462216
# TIMESTEP 320114 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.823443 / Loss  0.007887993939220905
# fps: 5.990955655286485
# TIMESTEP 320115 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.798365 / Loss  0.015746882185339928
# fps: 6.097169687895219
# TIMESTEP 320116 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.995108 / Loss  0.009493318386375904
# fps: 5.970802982053301
# TIMESTEP 320117 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.625326 / Loss  0.008182346820831299
# fps: 6.095645577125982
# TIMESTEP 320118 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.0861635 / Loss  0.03385716304183006
# fps: 6.118382261770176
# TIMESTEP 320119 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.822715 / Loss  0.005792789161205292
# fps: 5.9541644899720625
# TIMESTEP 320120 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.908381 / Loss  0.03169959411025047
# fps: 6.036081465363405
# TIMESTEP 320121 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.705473 / Loss  0.03171040490269661
# fps: 6.143628022522074
# TIMESTEP 320122 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.244808 / Loss  0.048689231276512146
# fps: 5.951764966312671
# TIMESTEP 320123 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.975339 / Loss  0.023605480790138245
# fps: 6.01588342022791
# TIMESTEP 320124 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.194627 / Loss  0.024496495723724365
# fps: 6.132050286770264
# TIMESTEP 320125 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.071356 / Loss  0.004357010126113892
# fps: 5.995897239428244
# TIMESTEP 320126 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.975541 / Loss  0.00271231634542346
# fps: 6.06713871390032
# TIMESTEP 320127 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.70193 / Loss  0.8360134959220886
# fps: 7.223612646778199
# TIMESTEP 320128 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.169338 / Loss  0.017084412276744843
# fps: 7.1122204662456845
# TIMESTEP 320129 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.123213 / Loss  0.5646559000015259
# fps: 3.846788934450662
# TIMESTEP 320130 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.089486 / Loss  0.0038085365667939186
# fps: 5.32976855181598
# TIMESTEP 320131 / STATE train / EPSILON 0 / ACTION 1 / REWARD -1 / Q_MAX  9.967242 / Loss  0.008977307006716728
# fps: 7.161450489859615
# TIMESTEP 320132 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.078165 / Loss  0.004332166630774736
# fps: 6.073472981230651
# TIMESTEP 320133 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.052354 / Loss  0.022141113877296448
# fps: 6.077662080977456
# TIMESTEP 320134 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.898521 / Loss  0.0037205186672508717
# fps: 7.066245036381617
# TIMESTEP 320135 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.996009 / Loss  0.018998583778738976
# fps: 7.306869771541857
# TIMESTEP 320136 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.975431 / Loss  0.0089121013879776
# fps: 6.94735203163019
# TIMESTEP 320137 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.887525 / Loss  0.08745185285806656
# fps: 7.195876996136399
# TIMESTEP 320138 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.875695 / Loss  0.012906130403280258
# fps: 6.952465095154347
# TIMESTEP 320139 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.826666 / Loss  0.033433519303798676
# fps: 7.157283296275376
# TIMESTEP 320140 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.917468 / Loss  0.019437376409769058
# fps: 6.854703564547049
# TIMESTEP 320141 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.928915 / Loss  0.012734012678265572
# fps: 7.246426288419343
# TIMESTEP 320142 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.807378 / Loss  0.042942073196172714
# fps: 6.897709481771895
# TIMESTEP 320143 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.016662 / Loss  0.01777191087603569
# fps: 7.142024721125341
# TIMESTEP 320144 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.87591 / Loss  0.007534493692219257
# fps: 7.016502809576147
# TIMESTEP 320145 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.744456 / Loss  0.005553809925913811
# fps: 7.270455557924551
# TIMESTEP 320146 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.955148 / Loss  0.009252497926354408
# fps: 5.848042776573273
# TIMESTEP 320147 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.183271 / Loss  0.005413854029029608
# fps: 7.09126167631768
# TIMESTEP 320148 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.842051 / Loss  0.007063411176204681
# fps: 6.004558208784287
# TIMESTEP 320149 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.850975 / Loss  0.010453516617417336
# fps: 5.980423161980155
# TIMESTEP 320150 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.906052 / Loss  0.00535472109913826
# fps: 5.964324717874044
# TIMESTEP 320151 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.980751 / Loss  0.015237869694828987
# fps: 6.32392302078873
# TIMESTEP 320152 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.960109 / Loss  0.29950836300849915
# fps: 5.9907502892319995
# TIMESTEP 320153 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.9245205 / Loss  0.010339953005313873
# fps: 6.012184039195337
# TIMESTEP 320154 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.943047 / Loss  0.006561215966939926
# fps: 6.084795062881813
# TIMESTEP 320155 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.893863 / Loss  0.015879280865192413
# fps: 6.021739286488535
# TIMESTEP 320156 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.761438 / Loss  0.019227616488933563
# fps: 5.957496612398763
# TIMESTEP 320157 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.894702 / Loss  0.22981657087802887
# fps: 7.091453507343704
# TIMESTEP 320158 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.334125 / Loss  0.013983014971017838
# fps: 7.107857392212089
# TIMESTEP 320159 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.861307 / Loss  0.008979521691799164
# fps: 5.927440051553968
# TIMESTEP 320160 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.018035 / Loss  0.01984870806336403
# fps: 5.994654653452894
# TIMESTEP 320161 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.03558 / Loss  0.008131861686706543
# fps: 6.070739103060479
# TIMESTEP 320162 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.224883 / Loss  0.24207845330238342
# fps: 5.941125644141885
# TIMESTEP 320163 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.92363 / Loss  0.016553610563278198
# fps: 3.4467093050297435
# TIMESTEP 320164 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.284745 / Loss  0.15126918256282806
# fps: 7.012877746678571
# TIMESTEP 320165 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.171949 / Loss  0.020765874534845352
# fps: 6.057736413687123
# TIMESTEP 320166 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.192281 / Loss  0.018290987238287926
# fps: 6.011580842305619
# TIMESTEP 320167 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.240819 / Loss  1.818074107170105
# fps: 5.983972561893389
# TIMESTEP 320168 / STATE train / EPSILON 0 / ACTION 1 / REWARD -1 / Q_MAX  10.201352 / Loss  0.6504520177841187
# fps: 5.989646687868346
# TIMESTEP 320169 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.244806 / Loss  0.013849696144461632
# fps: 5.935979846870179
# TIMESTEP 320170 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.155407 / Loss  0.012014087289571762
# fps: 6.0688329990942265
# TIMESTEP 320171 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.287583 / Loss  0.021564042195677757
# fps: 7.158590368519505
# TIMESTEP 320172 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.19475 / Loss  0.022787166759371758
# fps: 7.151742705972824
# TIMESTEP 320173 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.142023 / Loss  0.029632776975631714
# fps: 7.221834047601419
# TIMESTEP 320174 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.08012 / Loss  0.006536497734487057
# fps: 6.91583866191354
# TIMESTEP 320175 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.624673 / Loss  0.013342189602553844
# fps: 6.987071356583013
# TIMESTEP 320176 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.03972 / Loss  0.013364534825086594
# fps: 7.038343944341709
# TIMESTEP 320177 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.305117 / Loss  0.012661522254347801
# fps: 7.15962903724137
# TIMESTEP 320178 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.388964 / Loss  0.009469468146562576
# fps: 6.928817098433613
# TIMESTEP 320179 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.101976 / Loss  0.02340463548898697
# fps: 7.19893997542171
# TIMESTEP 320180 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.065984 / Loss  0.10057839751243591
# fps: 6.957608773184128
# TIMESTEP 320181 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.134021 / Loss  0.05180760845541954
# fps: 7.184180190981887
# TIMESTEP 320182 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.418895 / Loss  0.01254403218626976
# fps: 6.930099301092147
# TIMESTEP 320183 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.403603 / Loss  0.08156277984380722
# fps: 7.247215104354753
# TIMESTEP 320184 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.238222 / Loss  0.0213266983628273
# fps: 6.931049811037648
# TIMESTEP 320185 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.235319 / Loss  0.012403502129018307
# fps: 7.194655002358592
# TIMESTEP 320186 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.276084 / Loss  0.02407602034509182
# fps: 6.986978242654127
# TIMESTEP 320187 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.327284 / Loss  0.018533051013946533
# fps: 7.125571881683987
# TIMESTEP 320188 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.365924 / Loss  0.3269802927970886
# fps: 7.043757473163785
# TIMESTEP 320189 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.6743178 / Loss  0.04758094251155853
# fps: 7.115224696895415
# TIMESTEP 320190 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.675167 / Loss  0.010274015367031097
# fps: 6.999302456753988
# TIMESTEP 320191 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.440697 / Loss  4.549081802368164
# fps: 6.139419417543942
# TIMESTEP 320192 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.7844945 / Loss  0.0654611587524414
# fps: 6.97722667855515
# TIMESTEP 320193 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.497444 / Loss  0.03517255187034607
# fps: 5.996180106819767
# TIMESTEP 320194 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.218588 / Loss  0.014410736039280891
# fps: 7.3873423874850515
# TIMESTEP 320195 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.234269 / Loss  0.014076435007154942
# fps: 7.095736438042842
# TIMESTEP 320196 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.974678 / Loss  0.13515330851078033
# fps: 7.227371729480852
# TIMESTEP 320197 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.244016 / Loss  0.05277569964528084
# fps: 3.7219346623303444
# TIMESTEP 320198 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.972369 / Loss  0.04436544328927994
# fps: 5.861142630363941
# TIMESTEP 320199 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.966879 / Loss  0.016349196434020996
# fps: 6.167976200454992
# TIMESTEP 320200 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.246117 / Loss  0.012538754381239414
# fps: 6.168583975786312
# TIMESTEP 320201 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.234467 / Loss  0.016837310045957565
# fps: 7.170767818340038
# TIMESTEP 320202 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.083181 / Loss  0.04544016718864441
# fps: 7.108339236747823
# TIMESTEP 320203 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.91152 / Loss  0.007033988833427429
# fps: 7.204380715507705
# TIMESTEP 320204 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.904042 / Loss  0.15042810142040253
# fps: 6.027086874864386
# TIMESTEP 320205 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.178648 / Loss  0.027088120579719543
# fps: 6.09202444185908
# TIMESTEP 320206 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.348351 / Loss  0.025655489414930344
# fps: 5.9613238466939364
# TIMESTEP 320207 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.120563 / Loss  0.010201681405305862
# fps: 7.086600975899869
# TIMESTEP 320208 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.092672 / Loss  0.010808351449668407
# fps: 7.1621597623032
# TIMESTEP 320209 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.7574215 / Loss  0.012280279770493507
# fps: 6.129218647022634
# TIMESTEP 320210 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.112273 / Loss  0.01818905770778656
# fps: 6.190361211062144
# TIMESTEP 320211 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.166412 / Loss  0.07597428560256958
# fps: 6.161262364965905
# TIMESTEP 320212 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.224681 / Loss  0.015630368143320084
# fps: 7.00137045983017
# TIMESTEP 320213 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.016654 / Loss  1.4684945344924927
# fps: 7.123139524614998
# TIMESTEP 320214 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.564869 / Loss  0.007092424668371677
# fps: 6.9942135998746
# TIMESTEP 320215 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.11495 / Loss  0.011492684483528137
# fps: 7.171478937658478
# TIMESTEP 320216 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.762928 / Loss  0.018673043698072433
# fps: 6.992790978386273
# TIMESTEP 320217 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.814672 / Loss  0.011247925460338593
# fps: 7.226898517163071
# TIMESTEP 320218 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.253225 / Loss  0.024547195062041283
# fps: 7.013804186238622
# TIMESTEP 320219 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.990563 / Loss  0.015323972329497337
# fps: 7.313533240685685
# TIMESTEP 320220 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.425472 / Loss  0.25975990295410156
# fps: 7.0152001712695355
# TIMESTEP 320221 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.335283 / Loss  0.013212854973971844
# fps: 6.915804452241702
# TIMESTEP 320222 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.392244 / Loss  0.01617772877216339
# fps: 6.112114341006196
# TIMESTEP 320223 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.766262 / Loss  0.02873111329972744
# fps: 6.093520183867434
# TIMESTEP 320224 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.474317 / Loss  0.0066551510244607925
# fps: 7.347368347294774
# TIMESTEP 320225 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.637008 / Loss  0.020903021097183228
# fps: 7.241546961325967
# TIMESTEP 320226 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.42901 / Loss  1.543411374092102
# fps: 7.454194857795858
# TIMESTEP 320227 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.512738 / Loss  0.01213240996003151
# fps: 7.348938913963724
# TIMESTEP 320228 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.661016 / Loss  0.09241453558206558
# fps: 6.155448292258405
# TIMESTEP 320229 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.627295 / Loss  0.027287032455205917
# fps: 5.930951980305124
# TIMESTEP 320230 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.74108 / Loss  0.023537663742899895
# fps: 2.9653837397891154
# TIMESTEP 320231 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.0569 / Loss  0.018968064337968826
# fps: 6.447329870616971
# TIMESTEP 320232 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  11.00119 / Loss  0.1753404140472412
# fps: 5.344022302095026
# TIMESTEP 320233 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.946184 / Loss  0.09013689309358597
# fps: 6.09061787555362
# TIMESTEP 320234 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.145903 / Loss  0.020314909517765045
# fps: 6.174986492275937
# TIMESTEP 320235 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.122203 / Loss  0.02848680689930916
# fps: 6.011649772967023
# TIMESTEP 320236 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.084973 / Loss  0.012560165487229824
# fps: 7.176779991341947
# TIMESTEP 320237 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  11.287255 / Loss  0.02104402892291546
# fps: 7.0884812922612035
# TIMESTEP 320238 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  11.04425 / Loss  0.02227640710771084
# fps: 5.9674304917295755
# TIMESTEP 320239 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.031025 / Loss  0.03193362429738045
# fps: 6.033146818946793
# TIMESTEP 320240 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.185184 / Loss  0.02264823019504547
# fps: 6.0940159763812245
# TIMESTEP 320241 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  3.54732 / Loss  0.06257369369268417
# fps: 5.903454410591105
# TIMESTEP 320242 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.989826 / Loss  0.01824082061648369
# fps: 7.102922249468251
# TIMESTEP 320243 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  11.3317995 / Loss  0.013636779971420765
# fps: 7.029873960847413
# TIMESTEP 320244 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  11.061892 / Loss  0.0952732190489769
# fps: 7.161438262256287
# TIMESTEP 320245 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  11.096507 / Loss  0.06679720431566238
# fps: 5.995931524963368
# TIMESTEP 320246 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.917196 / Loss  1.1954554319381714
# fps: 5.996480146855936
# TIMESTEP 320247 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.419979 / Loss  0.7940719723701477
# fps: 6.066217349801857
# TIMESTEP 320248 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.457732 / Loss  0.022206194698810577
# fps: 6.025822672058961
# TIMESTEP 320249 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.106314 / Loss  0.01621951535344124
# fps: 7.175245316071111
# TIMESTEP 320250 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.944967 / Loss  0.01592765934765339
# fps: 6.012649445224921
# TIMESTEP 320251 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.115246 / Loss  0.010860549286007881
# fps: 6.007215583827811
# TIMESTEP 320252 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.693668 / Loss  2.0125315189361572
# fps: 5.887494402793901
# TIMESTEP 320253 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.995994 / Loss  0.008686400018632412
# fps: 5.90935142735575
# TIMESTEP 320254 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.886642 / Loss  0.007591591216623783
# fps: 7.1394109817085
# TIMESTEP 320255 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  11.1143675 / Loss  0.014215854927897453
# fps: 6.962586694023632
# TIMESTEP 320256 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.589024 / Loss  0.03884506598114967
# fps: 7.094200226646144
# TIMESTEP 320257 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  11.09136 / Loss  0.05305030941963196
# fps: 5.9254805450933965
# TIMESTEP 320258 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.958112 / Loss  0.0055697825737297535
# fps: 5.989749331307381
# TIMESTEP 320259 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.9449835 / Loss  0.013121392577886581
# fps: 6.241310193252314
# TIMESTEP 320260 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.754542 / Loss  0.0081803472712636
# fps: 6.032747649786553
# TIMESTEP 320261 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.666163 / Loss  0.005619305185973644
# fps: 6.062306862889635
# TIMESTEP 320262 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.603226 / Loss  0.009595592506229877
# fps: 6.05381063655665
# TIMESTEP 320263 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.748118 / Loss  0.03357258066534996
# fps: 6.024083095872783
# TIMESTEP 320264 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.371507 / Loss  0.021343551576137543
# fps: 3.3761239850830247
# TIMESTEP 320265 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.607179 / Loss  3.9179704189300537
# fps: 5.895331022598537
# TIMESTEP 320266 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.732987 / Loss  0.0030314824543893337
# fps: 6.211841927930677
# TIMESTEP 320267 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.428428 / Loss  0.012433633208274841
# fps: 5.693445004004398
# TIMESTEP 320268 / STATE train / EPSILON 0 / ACTION 1 / REWARD -1 / Q_MAX  10.448163 / Loss  0.01700236275792122
# fps: 7.134274181888694
# TIMESTEP 320269 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.540481 / Loss  0.007346934638917446
# fps: 6.1308312857295295
# TIMESTEP 320270 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.485231 / Loss  0.1608574092388153
# fps: 5.98062782059417
# TIMESTEP 320271 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.527644 / Loss  0.008501320146024227
# fps: 6.121194962128398
# TIMESTEP 320272 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.552698 / Loss  0.044601745903491974
# fps: 6.137317276598235
# TIMESTEP 320273 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.1940775 / Loss  0.019518917426466942
# fps: 7.158468192011906
# TIMESTEP 320274 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.868149 / Loss  0.08648210018873215
# fps: 6.12911116793921
# TIMESTEP 320275 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.938774 / Loss  0.0104251429438591
# fps: 5.942522938119499
# TIMESTEP 320276 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.493599 / Loss  0.06624602526426315
# fps: 6.951209164191769
# TIMESTEP 320277 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.01398 / Loss  4.26943302154541
# fps: 6.119480246628986
# TIMESTEP 320278 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.523063 / Loss  0.012472396716475487
# fps: 7.039678823247047
# TIMESTEP 320279 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.207397 / Loss  0.728406548500061
# fps: 7.156184259241882
# TIMESTEP 320280 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.4911785 / Loss  0.021228061988949776
# fps: 7.012080501008102
# TIMESTEP 320281 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.861717 / Loss  0.036971352994441986
# fps: 7.14134374888265
# TIMESTEP 320282 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.132313 / Loss  0.017130183055996895
# fps: 7.059751058296794
# TIMESTEP 320283 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.779426 / Loss  0.18191437423229218
# fps: 7.223662410399666
# TIMESTEP 320284 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.717729 / Loss  0.019165746867656708
# fps: 7.107785121165904
# TIMESTEP 320285 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.796156 / Loss  0.019936274737119675
# fps: 7.271363065054393
# TIMESTEP 320286 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.970238 / Loss  0.010399214923381805
# fps: 7.000131847957609
# TIMESTEP 320287 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.903647 / Loss  0.011593824252486229
# fps: 7.1265404462175495
# TIMESTEP 320288 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.796282 / Loss  0.009184500202536583
# fps: 6.936115957367642
# TIMESTEP 320289 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.888078 / Loss  0.011998970061540604
# fps: 6.953836767446333
# TIMESTEP 320290 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.798388 / Loss  0.02122057043015957
# fps: 6.324895723691155
# TIMESTEP 320291 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.6590147 / Loss  0.1812700480222702
# fps: 5.009188818638469
# TIMESTEP 320292 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.735685 / Loss  0.033507537096738815
# fps: 4.207785745528674
# TIMESTEP 320293 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.659989 / Loss  3.3944602012634277
# fps: 6.02165283394852
# TIMESTEP 320294 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.411423 / Loss  0.01170297060161829
# fps: 6.684085889218589
# TIMESTEP 320295 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.5434065 / Loss  0.017178155481815338
# fps: 6.6400766228934645
# TIMESTEP 320296 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.365706 / Loss  0.011720092967152596
# fps: 6.6790194623412775
# TIMESTEP 320297 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.432147 / Loss  0.276969850063324
# fps: 6.725855463920501
# TIMESTEP 320298 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.339258 / Loss  0.05663830041885376
# fps: 3.147369353117651
# TIMESTEP 320299 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.490463 / Loss  0.014938184060156345
# fps: 5.460849820588802
# TIMESTEP 320300 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.055944 / Loss  0.0069526382721960545
# fps: 5.473384757323743
# TIMESTEP 320301 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.323793 / Loss  0.02031770721077919
# fps: 5.949257673262762
# TIMESTEP 320302 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.075198 / Loss  0.01841348223388195
# fps: 5.515170880325258
# TIMESTEP 320303 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.331092 / Loss  0.003672332502901554
# fps: 5.474027660499153
# TIMESTEP 320304 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.076177 / Loss  0.0124231968075037
# fps: 5.488928061517603
# TIMESTEP 320305 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.402694 / Loss  0.03619048371911049
# fps: 6.61784479643792
# TIMESTEP 320306 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.798225 / Loss  0.005036006681621075
# fps: 5.451048737473179
# TIMESTEP 320307 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.600219 / Loss  0.041076142340898514
# fps: 5.488841865024059
# TIMESTEP 320308 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.276719 / Loss  0.06416332721710205
# fps: 5.9968488085808485
# TIMESTEP 320309 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.050081 / Loss  0.03512981906533241
# fps: 5.99822954936454
# TIMESTEP 320310 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.313632 / Loss  0.00692222872748971
# fps: 6.574350293112637
# TIMESTEP 320311 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.404528 / Loss  0.014294522814452648
# fps: 6.1288156198948505
# TIMESTEP 320312 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.987148 / Loss  0.007644656579941511
# fps: 5.8901649519861365
# TIMESTEP 320313 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.444004 / Loss  0.47465819120407104
# fps: 5.58069331828935
# TIMESTEP 320314 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.425012 / Loss  0.019432321190834045
# fps: 5.960366577187121
# TIMESTEP 320315 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.546843 / Loss  0.015111780725419521
# fps: 5.46496240993368
# TIMESTEP 320316 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  3.7953818 / Loss  0.42985251545906067
# fps: 5.9629425856026845
# TIMESTEP 320317 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.54556 / Loss  0.33284685015678406
# fps: 6.011908277026543
# TIMESTEP 320318 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.5704155 / Loss  0.01716925948858261
# fps: 5.459982556398808
# TIMESTEP 320319 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.726765 / Loss  0.019097942858934402
# fps: 5.503779801778561
# TIMESTEP 320320 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.50435 / Loss  0.007320008706301451
# fps: 5.402976961077941
# TIMESTEP 320321 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.650844 / Loss  0.009990392252802849
# fps: 5.4587958462017
# TIMESTEP 320322 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.773653 / Loss  0.01258061919361353
# fps: 5.484886923272072
# TIMESTEP 320323 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  2.6505878 / Loss  1.0908424854278564
# fps: 6.6510271555996034
# TIMESTEP 320324 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.033131 / Loss  0.01317737065255642
# fps: 5.401251443899437
# TIMESTEP 320325 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.74141 / Loss  0.0038511990569531918
# fps: 5.457354012699073
# TIMESTEP 320326 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.926722 / Loss  0.009356099180877209
# fps: 6.050038296822734
# TIMESTEP 320327 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.869883 / Loss  0.008011732250452042
# fps: 6.708396243314482
# TIMESTEP 320328 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.766564 / Loss  0.13042113184928894
# fps: 6.618993588216078
# TIMESTEP 320329 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.84879 / Loss  0.04389548301696777
# fps: 5.474835075041835
# TIMESTEP 320330 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.861589 / Loss  0.00645533949136734
# fps: 5.458362505823653
# TIMESTEP 320331 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.862402 / Loss  0.024205494672060013
# fps: 5.456857005321156
# TIMESTEP 320332 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.812979 / Loss  0.06593597680330276
# fps: 3.5248681001548006
# TIMESTEP 320333 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.019426 / Loss  0.22788263857364655
# fps: 6.706948080087373
# TIMESTEP 320334 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.879299 / Loss  0.00661102682352066
# fps: 5.472285028761989
# TIMESTEP 320335 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.178105 / Loss  0.38362398743629456
# fps: 5.954046158257695
# TIMESTEP 320336 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.836552 / Loss  0.010228755883872509
# fps: 6.0320535683468135
# TIMESTEP 320337 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.949717 / Loss  0.021153954789042473
# fps: 5.488375014393836
# TIMESTEP 320338 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.788412 / Loss  0.010062109678983688
# fps: 5.446667047585408
# TIMESTEP 320339 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.124363 / Loss  0.033373523503541946
# fps: 5.995931524963368
# TIMESTEP 320340 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.075828 / Loss  0.013096032664179802
# fps: 5.462293502113002
# TIMESTEP 320341 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.01933 / Loss  2.1001791954040527
# fps: 6.6812856321353875
# TIMESTEP 320342 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.078972 / Loss  0.016340047121047974
# fps: 6.681455922950588
# TIMESTEP 320343 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.923143 / Loss  0.013689765706658363
# fps: 6.6874215751770185
# TIMESTEP 320344 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.942441 / Loss  0.006732933223247528
# fps: 5.466223040662676
# TIMESTEP 320345 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.132627 / Loss  0.019028402864933014
# fps: 6.033615476238427
# TIMESTEP 320346 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.46123 / Loss  0.04444842413067818
# fps: 5.4213508706622
# TIMESTEP 320347 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.969365 / Loss  0.006820160895586014
# fps: 5.505954506311567
# TIMESTEP 320348 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.908307 / Loss  0.01453678123652935
# fps: 6.649498232319229
# TIMESTEP 320349 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.578783 / Loss  0.013836666010320187
# fps: 6.053871801163345
# TIMESTEP 320350 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.912678 / Loss  0.016209019348025322
# fps: 5.950928967175784
# TIMESTEP 320351 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.262986 / Loss  2.8080546855926514
# fps: 6.055025422334119
# TIMESTEP 320352 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.917009 / Loss  0.0327485017478466
# fps: 5.435711878904124
# ...
# fps: 6.128081351177605
# TIMESTEP 330199 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.535197 / Loss  0.04825519770383835
# fps: 6.934854459628151
# TIMESTEP 330200 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.97817 / Loss  0.023208869621157646
# fps: 5.988107458322566
# TIMESTEP 330201 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.284979 / Loss  0.09847768396139145
# fps: 5.980994535643801
# TIMESTEP 330202 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.877578 / Loss  0.20277608931064606
# fps: 5.94858266923654
# TIMESTEP 330203 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.7938294 / Loss  0.025320488959550858
# fps: 5.968814705501471
# TIMESTEP 330204 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.5065975 / Loss  0.03315502777695656
# fps: 7.0478171665930125
# TIMESTEP 330205 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.243983 / Loss  0.034275345504283905
# fps: 7.0866728167905135
# TIMESTEP 330206 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.009561 / Loss  0.0851924940943718
# fps: 7.109941839670057
# TIMESTEP 330207 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.246496 / Loss  0.016530511900782585
# fps: 7.065066670260145
# TIMESTEP 330208 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.945784 / Loss  0.06991109251976013
# fps: 5.986808280437517
# TIMESTEP 330209 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.78935 / Loss  0.051863525062799454
# fps: 6.0177391354251855
# TIMESTEP 330210 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.133102 / Loss  0.8054493069648743
# fps: 5.998898708342213
# TIMESTEP 330211 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.088545 / Loss  0.02155841886997223
# fps: 7.050257599825185
# TIMESTEP 330212 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.1706295 / Loss  0.1632312387228012
# fps: 7.056769734473372
# TIMESTEP 330213 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.101264 / Loss  0.06094393879175186
# fps: 6.10037102810127
# TIMESTEP 330214 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.600785 / Loss  0.022372936829924583
# fps: 6.9645405380273875
# TIMESTEP 330215 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.81488 / Loss  0.017255999147892
# fps: 5.828903372847673
# TIMESTEP 330216 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.510138 / Loss  0.20275460183620453
# fps: 6.926929003298063
# TIMESTEP 330217 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.098978 / Loss  0.03716057538986206
# fps: 5.620718767337334
# TIMESTEP 330218 / STATE train / EPSILON 0 / ACTION 1 / REWARD -1 / Q_MAX  7.7925406 / Loss  0.13506284356117249
# fps: 6.142539347332934
# TIMESTEP 330219 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.9369373 / Loss  0.051564402878284454
# fps: 6.02420422784032
# TIMESTEP 330220 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.279291 / Loss  0.02610255777835846
# fps: 6.015892048812113
# TIMESTEP 330221 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.7114644 / Loss  0.06676138937473297
# fps: 6.155701242645321
# TIMESTEP 330222 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.39948 / Loss  0.05314730852842331
# fps: 5.9971489155441295
# TIMESTEP 330223 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.72466 / Loss  0.045958712697029114
# fps: 6.013709805765804
# TIMESTEP 330224 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.8158154 / Loss  0.058089479804039
# fps: 6.158268057584589
# TIMESTEP 330225 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.146935 / Loss  0.14195649325847626
# fps: 5.945943187327582
# TIMESTEP 330226 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.605219 / Loss  2.4337284564971924
# fps: 5.988440890919475
# TIMESTEP 330227 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.426676 / Loss  0.030742384493350983
# fps: 5.846159850358076
# TIMESTEP 330228 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.273975 / Loss  0.052003733813762665
# fps: 5.904734285098876
# TIMESTEP 330229 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.770319 / Loss  0.05076545104384422
# fps: 3.3760669175861504
# TIMESTEP 330230 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.7214775 / Loss  0.042958907783031464
# fps: 5.913208733545652
# TIMESTEP 330231 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.325623 / Loss  0.028332237154245377
# fps: 6.345823845798882
# TIMESTEP 330232 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.380617 / Loss  0.02692907676100731
# fps: 6.191329814244045
# TIMESTEP 330233 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.544542 / Loss  0.031185884028673172
# fps: 6.100521866618572
# TIMESTEP 330234 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.745114 / Loss  0.056552011519670486
# fps: 6.17232397495931
# TIMESTEP 330235 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.621754 / Loss  0.8828888535499573
# fps: 5.868818877365408
# TIMESTEP 330236 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.9717007 / Loss  0.08668015152215958
# fps: 5.989330226075831
# TIMESTEP 330237 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.593185 / Loss  0.29272520542144775
# fps: 7.109363373329785
# TIMESTEP 330238 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.726121 / Loss  0.059877660125494
# fps: 6.116695881956617
# TIMESTEP 330239 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.005333 / Loss  0.07673390209674835
# fps: 6.018049971734146
# TIMESTEP 330240 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.744798 / Loss  0.08198775351047516
# fps: 6.1436550193714705
# TIMESTEP 330241 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.7127495 / Loss  0.041050516068935394
# fps: 5.996763069250874
# TIMESTEP 330242 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.300002 / Loss  0.05103690177202225
# fps: 7.1302112728731615
# TIMESTEP 330243 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.643298 / Loss  0.020849719643592834
# fps: 5.997534811493155
# TIMESTEP 330244 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.91769 / Loss  0.02246220037341118
# fps: 6.111651221075945
# TIMESTEP 330245 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.865881 / Loss  0.09538254141807556
# fps: 6.140318207637217
# TIMESTEP 330246 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.727442 / Loss  0.1644180715084076
# fps: 6.926860364682509
# TIMESTEP 330247 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.990755 / Loss  0.029023684561252594
# fps: 6.272306647804253
# TIMESTEP 330248 / STATE train / EPSILON 0 / ACTION 0 / REWARD -1 / Q_MAX  8.1902685 / Loss  0.01746756210923195
# fps: 5.97956204379562
# TIMESTEP 330249 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.4571495 / Loss  0.03235876187682152
# fps: 6.0111500614829865
# TIMESTEP 330250 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.6135235 / Loss  0.016300074756145477
# fps: 5.864133648935263
# TIMESTEP 330251 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.59094 / Loss  0.05402142181992531
# fps: 6.073692853284755
# TIMESTEP 330252 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.536968 / Loss  0.01970638707280159
# fps: 6.964309256679457
# TIMESTEP 330253 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.445297 / Loss  1.7321094274520874
# fps: 7.1889948134664765
# TIMESTEP 330254 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.202578 / Loss  0.20673352479934692
# fps: 7.020014126043135
# TIMESTEP 330255 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.688611 / Loss  0.06883857399225235
# fps: 7.1400429665290055
# TIMESTEP 330256 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.236765 / Loss  0.3477696180343628
# fps: 5.9923508057084645
# TIMESTEP 330257 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.873252 / Loss  0.801954448223114
# fps: 6.123169861121857
# TIMESTEP 330258 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.837168 / Loss  0.03678188845515251
# fps: 5.9867484634555055
# TIMESTEP 330259 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.24764 / Loss  0.02947058156132698
# fps: 5.88740349793661
# TIMESTEP 330260 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.592859 / Loss  0.021432261914014816
# fps: 5.9821632068004025
# TIMESTEP 330261 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.669989 / Loss  1.999132513999939
# fps: 6.157843119982617
# TIMESTEP 330262 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.240232 / Loss  0.23208224773406982
# fps: 6.078904079411343
# TIMESTEP 330263 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.162706 / Loss  0.024488400667905807
# fps: 3.7000609574823766
# TIMESTEP 330264 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.09054 / Loss  0.04069441556930542
# fps: 6.798230059808419
# TIMESTEP 330265 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.134767 / Loss  0.009963483549654484
# fps: 6.897165033217128
# TIMESTEP 330266 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.95906 / Loss  0.03437459096312523
# fps: 7.267532908587162
# TIMESTEP 330267 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.202682 / Loss  0.01860383339226246
# fps: 6.009160655314942
# TIMESTEP 330268 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.019842 / Loss  0.3206305205821991
# fps: 6.032548085013354
# TIMESTEP 330269 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.100226 / Loss  0.049046799540519714
# fps: 6.091024739908569
# TIMESTEP 330270 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.940052 / Loss  0.04458487033843994
# fps: 6.879415570889421
# TIMESTEP 330271 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.672004 / Loss  0.77734375
# fps: 7.165120657079699
# TIMESTEP 330272 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.977864 / Loss  0.02598920837044716
# fps: 6.842358207543015
# TIMESTEP 330273 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.9970565 / Loss  0.01448950357735157
# fps: 7.223550443215538
# TIMESTEP 330274 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.26752 / Loss  0.036292463541030884
# fps: 7.016174170507105
# TIMESTEP 330275 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.155137 / Loss  0.10482385009527206
# fps: 6.140210338931441
# TIMESTEP 330276 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.1762705 / Loss  0.017409512773156166
# fps: 6.931794368366601
# TIMESTEP 330277 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.9762278 / Loss  0.041380882263183594
# fps: 7.1013588787641755
# TIMESTEP 330278 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.02226 / Loss  0.037235766649246216
# fps: 5.842479015124711
# TIMESTEP 330279 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.992367 / Loss  0.23165009915828705
# fps: 5.887626633052262
# TIMESTEP 330280 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.894928 / Loss  0.009500876069068909
# fps: 7.165634780707149
# TIMESTEP 330281 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.468819 / Loss  0.03737267851829529
# fps: 6.1658363334602475
# TIMESTEP 330282 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.659793 / Loss  0.049835268408060074
# fps: 6.106463734398272
# TIMESTEP 330283 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0.71316594 / Loss  0.2820659577846527
# fps: 6.03476138953475
# TIMESTEP 330284 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.311089 / Loss  0.034196749329566956
# fps: 5.673038115075608
# TIMESTEP 330285 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.477732 / Loss  0.02433856762945652
# fps: 6.0173506351904855
# TIMESTEP 330286 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.9710393 / Loss  0.04817696660757065
# fps: 6.176768844480115
# TIMESTEP 330287 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.60448 / Loss  0.018805140629410744
# fps: 7.039572486900362
# TIMESTEP 330288 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.700245 / Loss  0.015150886960327625
# fps: 7.191891618469853
# TIMESTEP 330289 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.492938 / Loss  0.028351739048957825
# fps: 5.952922241508759
# TIMESTEP 330290 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.511425 / Loss  0.07148133218288422
# fps: 6.008721613211926
# TIMESTEP 330291 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.604551 / Loss  0.9932701587677002
# fps: 6.02580535789454
# TIMESTEP 330292 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.726455 / Loss  0.3618469536304474
# fps: 6.978213380760893
# TIMESTEP 330293 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.893946 / Loss  0.022234300151467323
# fps: 7.300027847396269
# TIMESTEP 330294 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.5251665 / Loss  0.022479813545942307
# fps: 6.963060602790667
# TIMESTEP 330295 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.40641 / Loss  0.22861893475055695
# fps: 6.112185596455947
# TIMESTEP 330296 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.8236265 / Loss  0.02589726820588112
# fps: 6.023788938516997
# TIMESTEP 330297 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.594481 / Loss  0.009087298065423965
# fps: 3.550036310328892
# TIMESTEP 330298 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.228894 / Loss  0.029119806364178658
# fps: 5.983998173828683
# TIMESTEP 330299 / STATE train / EPSILON 0 / ACTION 0 / REWARD -1 / Q_MAX  8.602729 / Loss  0.03061351738870144
# fps: 7.002001619325059
# TIMESTEP 330300 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.4819145 / Loss  0.03552568703889847
# fps: 7.195593061576705
# TIMESTEP 330301 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.201715 / Loss  0.06982887536287308
# fps: 7.241609475219917
# TIMESTEP 330302 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.099216 / Loss  0.4117426872253418
# fps: 6.007723246513653
# TIMESTEP 330303 / STATE train / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.12439 / Loss  0.0450669601559639
# fps: 7.002328932013549
# TIMESTEP 330304 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.199802 / Loss  0.10721258819103241
# fps: 6.899479533356582
# TIMESTEP 330305 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.702607 / Loss  0.013387154787778854
# fps: 7.032773636220351
# TIMESTEP 330306 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.603284 / Loss  0.03420400619506836
# fps: 7.0988108576515705
# TIMESTEP 330307 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.988352 / Loss  0.021745163947343826
# fps: 7.031995439761258
# TIMESTEP 330308 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.605884 / Loss  0.030209464952349663
# fps: 7.226114117466667
# TIMESTEP 330309 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.530335 / Loss  3.8256583213806152
# fps: 6.990576572432391
# TIMESTEP 330310 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.598303 / Loss  0.03894224762916565
# fps: 7.066673630615315
# TIMESTEP 330311 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.969533 / Loss  0.13467253744602203
# fps: 6.813071572675618
# TIMESTEP 330312 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.930087 / Loss  0.03687619790434837
# fps: 7.219472228390058
# TIMESTEP 330313 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.203372 / Loss  0.052420563995838165
# fps: 7.092832598284586
# TIMESTEP 330314 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.129437 / Loss  0.0367373488843441
# fps: 7.181547807595041
# TIMESTEP 330315 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.758798 / Loss  2.602059841156006
# fps: 6.873981228213075
# TIMESTEP 330316 / STATE train / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.019282 / Loss  0.02839096076786518
# fps: 7.1435087175486975
