# %%
import numpy as np
from PIL import Image
import cv2 #opencv
import io
import time
import pandas as pd
import numpy as np
from IPython.display import clear_output
from random import randint
import os

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
from keras.callbacks import TensorBoard
from collections import deque
import random
import pickle
from io import BytesIO
import base64
import json
# Out:
# Using TensorFlow backend.

# %%
#path variables
game_url = "chrome://dino"
chrome_driver_path = "./chromedriver"
loss_file_path = "./objects/loss_df.csv"
actions_file_path = "./objects/actions_df.csv"
q_value_file_path = "./objects/q_values.csv"
scores_file_path = "./objects/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('runner-canvas')[0].id = 'runner-canvas'"

#get image from canvas
getbase64Script = "canvasRunner = document.getElementById('runner-canvas'); \
return canvasRunner.toDataURL().substring(22)"

# %% [markdown]
# setting path

# %%
'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* get_crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        self._driver = webdriver.Chrome(executable_path = chrome_driver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.get('chrome://dino')
        self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def get_crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %% [markdown]
# 銜接browser-javascript與python的模組，運行chrome並且連接至小恐龍遊戲的環境。
# 這裡可以得到狀態:撞毀、遊戲中、分數。指令:重啟遊戲、跳躍、暫停、恢復遊戲、結束。

# %%
class DinoAgent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %% [markdown]
# 這裡為DinoAgent的模組，可知Agent是否撞毀，並有跳躍與蹲下兩種行為。我們在遊戲中只考慮跳躍與不跳躍兩種。

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        is_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            is_over = True
        return image, reward, is_over #return the Experience tuple

# %% [markdown]
# 為了確認Game的state，這裡使用OpenCV的截圖來獲取環境的狀態(OpenCV中影像處理的速度有經過特別優化)，這裡的get_state方法為輸入一個action，然後回傳下一狀態的影像、reward(如果撞毀=-1，沒撞毀=0.1)、is_over(是否撞毀)。OpenCV平均可以達到5FPS的擷取速度，這對於每個跳Action後的State轉換已經足夠表示。

# %%
def save_obj(obj, name ):
    with open('objects/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name ):
    with open('objects/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = process_img(screen)#processing image as required
    return image

def process_img(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:300, :500] #Crop Region of Interest(ROI)
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %% [markdown]
# 儲存object方法，後面會儲存的資料有:行為，格式為(S,a,r,St+1,是否結束)、時間(為了辨認FPS的更新狀態)、epsilon(隨機行為的機率隨時間遞減的參數)，螢幕截圖(單純擷取chrome中的遊戲影像)，影像處理(只保留有興趣的影像區域，在小恐龍的遊戲中其實只在乎仙人掌與螢幕左邊界的距離。size為80*80)

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %% [markdown]
# 使用DateFrame儲存loss,score,action,q_values。

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100. # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_obj(INITIAL_EPSILON,"epsilon")
    t = 0
    save_obj(t,"time")
    D = deque()
    save_obj(D,"D")

# %%
'''Call only once to init file structure
'''
init_cache()

# %% [markdown]
# 如果想要執行訓練，第一次需要執行init_cache()，他會創建所需的檔案。在這之前須建立object空白資料夾以存放。

# %%
def buildmodel():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model.h5')
    print("We finish building the model")
    return model

# %% [markdown]
# # 建立模型
# 模型輸入為80x80x4，即每四張影像為一組State，再經過幾次捲積與池化，再展平成512的特徵向量，最後輸出(0,1)代表不跳與跳，這裡的類神經網路用來替代傳統的Q-table，由於影像為格式的state很難窮舉到Q-table中，因此使用類神經網路，好處是可以舉一反三，State的pixel值即使不盡相同，但是仍可以訓練出其特性。這個方法即為DQN，為一種off-policy learning。

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate wherther the model is to be trained(weight updates), else just play
'''
def trainNetwork(model,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_obj("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        #epsilon = load_obj("epsilon") 
        epsilon = 0
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_obj("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[0] = 1
            else: # predict the output
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1        # o=> do nothing, 1=> jump
                
        #We reduced the epsilon (exploration parameter) gradually
        #if epsilon >= FINAL_EPSILON and t > OBSERVE:
            #epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 
            #epsilon=0
        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    

                targets[i] = model.predict(state_t)  # predicted q values
                Q_sa = model.predict(state_t1)      #predict q values for next step
                
                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            loss += model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = np.max(Q_sa)
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        # save progress every 1000 iterations
        if t % 20000 == 0:
            print("Now we save model")
            game_state._game.pause() #pause game while saving to filesystem
            model.save_weights("model.h5", overwrite=True)
            save_obj(D,"D") #saving episodes
            save_obj(t,"time") #caching time steps
            save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects/loss_df.csv",index=False)
            scores_df.to_csv("./objects/scores_df.csv",index=False)
            actions_df.to_csv("./objects/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state,             "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t,             "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %% [markdown]
# # Training
# 這裡寫下訓練的過程，我們先觀察100次，然後到累積10萬筆之前都是EXPLORE狀態，但仍會訓練神經網路，這是因為epsilon(隨機動作的機率)在10萬次以後才會收斂到最低值，後面的狀態我們稱為訓練狀態。
# 訓練方式是這樣的:使用當前state預測下一步的action並且概率地(取決於epsilon)執行，這時候觀察St+1與reward並記錄下來，然後從replay buffer中隨機取出32筆資料出來訓練，得到32組(S,A,r,St+1,terminal)，如果恐龍在此State,S採取Action,A，陣亡了，那麼reward就不更新，但如果沒有陣亡，則reward=reward+GAMMA*max(Q_sa)，意思是此State的Action會讓你的恐龍活著，所以是好棒棒的，所以多給一點reward，然後在拿其S,A,r進行supervised learning，Ptrue為更新過的reward，在進行反向傳播法更新參數，如此一來網路就會更像理想的Q_table，

# %%
#main function
def playGame(observe=False):
    game = Game()
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)    
    model = buildmodel()
    try:
        trainNetwork(model,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
playGame(observe=False);
# Out:
# Now we build the model
# We finish building the model
# fps: 3.941933531449538
# TIMESTEP 1 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.724715900262087
# TIMESTEP 2 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.72381573904306
# TIMESTEP 3 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.03789455732837
# TIMESTEP 4 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.722915652417107
# TIMESTEP 5 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 20.604451693087643
# TIMESTEP 6 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.72381573904306
# TIMESTEP 7 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 10.74498270782631
# TIMESTEP 8 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 5.693970584641784
# TIMESTEP 9 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 6.284787840101652
# TIMESTEP 10 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.724378331062987
# TIMESTEP 11 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 13.783224067958134
# TIMESTEP 12 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 30.747098883537493
# TIMESTEP 13 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.261742789070816
# TIMESTEP 14 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.257324731008406
# TIMESTEP 15 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 35.062688613393746
# TIMESTEP 16 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 30.747324282321202
# TIMESTEP 17 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 33.87174248358624
# TIMESTEP 18 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 31.72575923754775
# TIMESTEP 19 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 30.280722526242833
# TIMESTEP 20 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.724378331062987
# TIMESTEP 21 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 28.550937334077574
# TIMESTEP 22 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 23.239330020001884
# TIMESTEP 23 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.96235148735188
# TIMESTEP 24 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.037472476212926
# TIMESTEP 25 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 20.393665488386567
# TIMESTEP 26 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 22.460301055461247
# TIMESTEP 27 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 30.747098883537493
# TIMESTEP 28 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.49040584922965
# TIMESTEP 29 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 31.723839561919025
# TIMESTEP 30 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.72381573904306
# TIMESTEP 31 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 29.82573758950984
# TIMESTEP 32 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 22.211946131726254
# TIMESTEP 33 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 33.873383781688375
# TIMESTEP 34 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 32.76364857792324
# TIMESTEP 35 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 31.723599618799824
# TIMESTEP 36 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 20.816644167394585
# TIMESTEP 37 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.03958305117054
# TIMESTEP 38 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 22.20653652906389
# TIMESTEP 39 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 31.228531010349194
# TIMESTEP 40 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 20.8181940011813
# TIMESTEP 41 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.96235148735188
# TIMESTEP 42 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.261635009707458
# TIMESTEP 43 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.490185630184502
# TIMESTEP 44 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 19.985819387794
# TIMESTEP 45 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 22.971914296981115
# TIMESTEP 46 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.03377998876675
# TIMESTEP 47 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.494480715815797
# TIMESTEP 48 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.48963510231686
# TIMESTEP 49 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 20.818813999315026
# TIMESTEP 50 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 19.788093092597222
# TIMESTEP 51 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 20.818503995632103
# TIMESTEP 52 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 23.792609736450995
# TIMESTEP 53 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 30.74687348805841
# TIMESTEP 54 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.490075522354413
# TIMESTEP 55 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.72392825511594
# TIMESTEP 56 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 33.30954026000842
# TIMESTEP 57 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 31.22783349340719
# TIMESTEP 58 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 31.228065995592353
# TIMESTEP 59 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.48996541565262
# TIMESTEP 60 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.48776351853275
# TIMESTEP 61 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 30.75160748718776
# TIMESTEP 62 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 22.206889248917268
# TIMESTEP 63 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 32.763904511936005
# TIMESTEP 64 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.260880584758564
# TIMESTEP 65 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.03789455732837
# TIMESTEP 66 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.962811496913176
# TIMESTEP 67 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.037577994903998
# TIMESTEP 68 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.489855310079108
# TIMESTEP 69 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 19.21718333348606
# TIMESTEP 70 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 23.783840182363583
# TIMESTEP 71 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 20.6063750343906
# TIMESTEP 72 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.967757817000994
# TIMESTEP 73 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 20.393566330202074
# TIMESTEP 74 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 22.982991408030863
# TIMESTEP 75 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 32.235608773844476
# TIMESTEP 76 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.72347819781745
# TIMESTEP 77 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 32.23486554408724
# TIMESTEP 78 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 19.985724156005052
# TIMESTEP 79 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 23.239201258837348
# TIMESTEP 80 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.037683514653587
# TIMESTEP 81 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.037683514653587
# TIMESTEP 82 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.261635009707458
# TIMESTEP 83 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.037366958580357
# TIMESTEP 84 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 22.206301388719762
# TIMESTEP 85 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.261635009707458
# TIMESTEP 86 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.490185630184502
# TIMESTEP 87 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 32.23486554408724
# TIMESTEP 88 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 30.738536177822077
# TIMESTEP 89 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.494590868792056
# TIMESTEP 90 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 33.30954026000842
# TIMESTEP 91 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.490846300860287
# TIMESTEP 92 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 31.723599618799824
# TIMESTEP 93 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 30.743943647518453
# TIMESTEP 94 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 22.20653652906389
# TIMESTEP 95 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 32.76288079987502
# TIMESTEP 96 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.261419454258817
# TIMESTEP 97 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 1.089738699911767
# TIMESTEP 98 / STATE observe / EPSILON 0 / ACTION 1 / REWARD -1 / Q_MAX  0 / Loss  0
# fps: 27.758097179388756
# TIMESTEP 99 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 31.723599618799824
# TIMESTEP 100 / STATE observe / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 21.96212148979731
# TIMESTEP 101 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# fps: 30.28115975511147
# TIMESTEP 102 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.747903 / Loss  0.6636682748794556
# fps: 1.0867764644184237
# TIMESTEP 103 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.376387 / Loss  0.9207525253295898
# fps: 12.649257354826062
# TIMESTEP 104 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.850493 / Loss  1.282903790473938
# fps: 12.18594272963927
# TIMESTEP 105 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  13.224089 / Loss  1.0065724849700928
# fps: 11.228406827575867
# TIMESTEP 106 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.194602 / Loss  0.9806396961212158
# fps: 9.043365768360863
# TIMESTEP 107 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.445206 / Loss  9.957944869995117
# fps: 10.86182348355954
# TIMESTEP 108 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  14.779649 / Loss  1.1443283557891846
# fps: 10.630736671355612
# TIMESTEP 109 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.922843 / Loss  0.913979709148407
# fps: 12.186367598349701
# TIMESTEP 110 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.162107 / Loss  0.904164731502533
# fps: 13.503832891716382
# TIMESTEP 111 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.891442 / Loss  0.9267474412918091
# fps: 12.894283149493981
# TIMESTEP 112 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.986855 / Loss  0.6892839670181274
# fps: 12.729801175767177
# TIMESTEP 113 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.793164 / Loss  1.122281551361084
# fps: 10.74506528806421
# TIMESTEP 114 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.264269 / Loss  0.664506196975708
# fps: 10.409226164624597
# TIMESTEP 115 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.795747 / Loss  1.7075245380401611
# fps: 10.803156745173188
# TIMESTEP 116 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.729729 / Loss  0.7962329387664795
# fps: 10.46381215400697
# TIMESTEP 117 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  13.024355 / Loss  4.499736309051514
# fps: 10.744927655039554
# TIMESTEP 118 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.775806 / Loss  1.0052075386047363
# fps: 10.92135837894419
# TIMESTEP 119 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.703429 / Loss  3.155632495880127
# fps: 9.0433267716111
# TIMESTEP 120 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.184932 / Loss  0.9919987916946411
# fps: 10.40829625512126
# TIMESTEP 121 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.64771 / Loss  0.874854564666748
# fps: 10.981319495534745
# TIMESTEP 122 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.092089 / Loss  1.1277024745941162
# fps: 10.803128919842678
# TIMESTEP 123 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.5859113 / Loss  0.43739452958106995
# fps: 10.355283428797156
# TIMESTEP 124 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.7277565 / Loss  1.172802209854126
# fps: 10.86190786952153
# TIMESTEP 125 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.099507 / Loss  1.3819103240966797
# fps: 10.40927783113573
# TIMESTEP 126 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.2451987 / Loss  0.7167270183563232
# fps: 11.041884513523616
# TIMESTEP 127 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.08563 / Loss  1.6998497247695923
# fps: 12.729646636782189
# TIMESTEP 128 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  2.869621 / Loss  1.9117432832717896
# fps: 10.409303664583634
# TIMESTEP 129 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  3.3935707 / Loss  1.0687782764434814
# fps: 11.042000789785442
# TIMESTEP 130 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.2488556 / Loss  1.0827722549438477
# fps: 12.729801175767177
# TIMESTEP 131 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  2.2384026 / Loss  1.0542582273483276
# fps: 12.569613349076677
# TIMESTEP 132 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.9483523 / Loss  0.7138950228691101
# fps: 13.062705160546887
# TIMESTEP 133 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5614356 / Loss  0.444040983915329
# fps: 12.569199003886759
# TIMESTEP 134 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.5654564 / Loss  1.2027124166488647
# fps: 15.862519665980878
# TIMESTEP 135 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  3.3115826 / Loss  1.0063380002975464
# fps: 12.97778712897327
# TIMESTEP 136 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.14618 / Loss  1.634326457977295
# fps: 12.72976254066916
# TIMESTEP 137 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  3.196473 / Loss  0.5496939420700073
# fps: 12.811455555657371
# TIMESTEP 138 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  0.6038274 / Loss  0.686376690864563
# fps: 13.148535709135595
# TIMESTEP 139 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.9006352 / Loss  1.1578012704849243
# fps: 12.72976254066916
# TIMESTEP 140 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  1.577422 / Loss  0.5919297933578491
# fps: 12.649333651001408
# TIMESTEP 141 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.0892196 / Loss  0.6314630508422852
# fps: 12.81141642332645
# TIMESTEP 142 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  2.9933646 / Loss  0.805189847946167
# fps: 12.893966036668592
# TIMESTEP 143 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.859298 / Loss  0.8062832355499268
# fps: 12.649181059571093
# TIMESTEP 144 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.9616914 / Loss  0.6733856201171875
# fps: 12.97786743979529
# TIMESTEP 145 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  3.2446015 / Loss  0.8149788975715637
# fps: 10.68756800281312
# TIMESTEP 146 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  2.9308681 / Loss  0.9515091180801392
# fps: 10.518788997451999
# TIMESTEP 147 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.0303535 / Loss  0.9452688097953796
# fps: 10.981319495534745
# TIMESTEP 148 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  3.9925394 / Loss  0.29657119512557983
# fps: 10.574399907222292
# TIMESTEP 149 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.7465076 / Loss  0.8415642976760864
# fps: 12.491226398236941
# TIMESTEP 150 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  3.5524912 / Loss  0.5073165893554688
# fps: 13.062623796295142
# TIMESTEP 151 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.317915 / Loss  0.4010034203529358
# fps: 12.811259896393315
# TIMESTEP 152 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.350524 / Loss  0.7261713147163391
# fps: 12.729801175767177
# TIMESTEP 153 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.331599 / Loss  0.3816341757774353
# fps: 13.062583114549367
# TIMESTEP 154 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.200351 / Loss  0.6678966879844666
# fps: 12.729994354775071
# TIMESTEP 155 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.1130447 / Loss  0.8835963606834412
# fps: 12.413553884355736
# TIMESTEP 156 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.3332825 / Loss  0.9370976090431213
# fps: 13.413359940645227
# TIMESTEP 157 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.921941 / Loss  1.4606168270111084
# fps: 12.649219207083531
# TIMESTEP 158 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.782979 / Loss  0.34571534395217896
# fps: 12.729839811099714
# TIMESTEP 159 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.895685 / Loss  0.30001023411750793
# fps: 12.811338159381776
# TIMESTEP 160 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.8257704 / Loss  0.4766761064529419
# fps: 10.860782831159954
# TIMESTEP 161 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.318584 / Loss  0.6077823638916016
# fps: 10.410285430627948
# TIMESTEP 162 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.106051 / Loss  0.6097198724746704
# fps: 12.413517145038801
# TIMESTEP 163 / STATE explore / EPSILON 0 / ACTION 1 / REWARD -1 / Q_MAX  5.3396907 / Loss  1.0408294200897217
# fps: 10.803212396264223
# TIMESTEP 164 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.778973 / Loss  0.5765620470046997
# fps: 10.98117574367594
# TIMESTEP 165 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.242416 / Loss  0.6295424699783325
# fps: 7.9943277551176
# TIMESTEP 166 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.615161 / Loss  0.5582984089851379
# fps: 10.803156745173188
# TIMESTEP 167 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.477695 / Loss  0.5118862986564636
# fps: 12.72976254066916
# TIMESTEP 168 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.7993894 / Loss  0.3898557424545288
# fps: 10.68756800281312
# TIMESTEP 169 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.1508102 / Loss  0.760633647441864
# fps: 10.630413349655436
# TIMESTEP 170 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.246148 / Loss  0.6302715539932251
# fps: 10.463838258847714
# TIMESTEP 171 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.1536775 / Loss  0.5737916231155396
# fps: 10.803435006362077
# TIMESTEP 172 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.4741874 / Loss  0.8556112051010132
# fps: 13.062583114549367
# TIMESTEP 173 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.635669 / Loss  1.7579289674758911
# fps: 12.729839811099714
# TIMESTEP 174 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.614599 / Loss  1.7286550998687744
# fps: 10.518788997451999
# TIMESTEP 175 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.013857 / Loss  1.6153534650802612
# fps: 10.74506528806421
# TIMESTEP 176 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.9393086 / Loss  0.2150413990020752
# fps: 10.803128919842678
# TIMESTEP 177 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.2925286 / Loss  0.2549709677696228
# fps: 12.413553884355736
# TIMESTEP 178 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  6.3166337 / Loss  0.8695200681686401
# fps: 10.861879740721847
# TIMESTEP 179 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.080875 / Loss  3.1901638507843018
# fps: 10.68756800281312
# TIMESTEP 180 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.8639774 / Loss  0.2692473232746124
# fps: 10.687595236032474
# TIMESTEP 181 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.9867826 / Loss  0.4186607599258423
# fps: 15.9886555102352
# TIMESTEP 182 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  5.6070356 / Loss  0.5452141761779785
# fps: 12.811377291234587
# TIMESTEP 183 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.7204795 / Loss  2.830873966217041
# fps: 12.811259896393315
# TIMESTEP 184 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  5.546751 / Loss  2.3842225074768066
# fps: 16.117866324401387
# TIMESTEP 185 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  5.9153323 / Loss  0.5314016342163086
# fps: 12.894005674918764
# TIMESTEP 186 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.794872 / Loss  1.8491854667663574
# fps: 12.413590623890139
# TIMESTEP 187 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.600978 / Loss  0.4568420350551605
# fps: 13.148535709135595
# TIMESTEP 188 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.996217 / Loss  0.49623286724090576
# fps: 12.729801175767177
# TIMESTEP 189 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.863059 / Loss  0.6493097543716431
# fps: 12.569688687500749
# TIMESTEP 190 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.1380944 / Loss  0.4175844192504883
# fps: 12.97778712897327
# TIMESTEP 191 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.231926 / Loss  0.3446422219276428
# fps: 12.977827284260032
# TIMESTEP 192 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.450583 / Loss  0.40680551528930664
# fps: 12.261178671655752
# TIMESTEP 193 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.999539 / Loss  0.32241690158843994
# fps: 13.323837266555907
# TIMESTEP 194 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.766794 / Loss  0.6015170812606812
# fps: 12.56818209058983
# TIMESTEP 195 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.365229 / Loss  0.33212223649024963
# fps: 12.571195645658246
# TIMESTEP 196 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.6318183 / Loss  0.32086342573165894
# fps: 10.921273066718049
# TIMESTEP 197 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.24397 / Loss  0.25176066160202026
# fps: 9.084479098982023
# TIMESTEP 198 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.74961 / Loss  0.35732144117355347
# fps: 10.803101094655505
# TIMESTEP 199 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.178724 / Loss  0.5685155391693115
# fps: 12.811494688227352
# TIMESTEP 200 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.141777 / Loss  2.4100844860076904
# fps: 12.811338159381776
# TIMESTEP 201 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.8215065 / Loss  0.6642405986785889
# fps: 12.72976254066916
# TIMESTEP 202 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.817078 / Loss  1.7791600227355957
# fps: 12.729878446666769
# TIMESTEP 203 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.857563 / Loss  0.34226009249687195
# fps: 12.811338159381776
# TIMESTEP 204 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.297197 / Loss  0.35067296028137207
# fps: 12.894084952150243
# TIMESTEP 205 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.145391 / Loss  0.4965343475341797
# fps: 10.745092815092251
# TIMESTEP 206 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.079951 / Loss  0.5956228971481323
# fps: 16.248678970449227
# TIMESTEP 207 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.908698 / Loss  0.22969657182693481
# fps: 15.613916746703595
# TIMESTEP 208 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.3131976 / Loss  0.2867915630340576
# fps: 12.97778712897327
# TIMESTEP 209 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.7353578 / Loss  0.9491228461265564
# fps: 15.9886555102352
# TIMESTEP 210 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.129387 / Loss  0.4151580035686493
# fps: 15.736882192048085
# TIMESTEP 211 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  6.7158484 / Loss  0.6363164782524109
# fps: 15.86161985546324
# TIMESTEP 212 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.1093593 / Loss  0.5097703337669373
# fps: 16.51716968054943
# TIMESTEP 213 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  6.8415413 / Loss  0.2252279818058014
# fps: 10.629685947732295
# TIMESTEP 214 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.218884 / Loss  0.38234788179397583
# fps: 12.979313204581112
# TIMESTEP 215 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.428995 / Loss  0.291490375995636
# fps: 12.649295502798687
# TIMESTEP 216 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.538099 / Loss  0.5943695902824402
# fps: 11.967552422012538
# TIMESTEP 217 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.66091 / Loss  0.5912091732025146
# fps: 11.164357563610134
# TIMESTEP 218 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.41805 / Loss  0.6369469165802002
# fps: 10.80396374211463
# TIMESTEP 219 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.1882763 / Loss  0.38354480266571045
# fps: 10.463786049296477
# TIMESTEP 220 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.423811 / Loss  0.17576099932193756
# fps: 13.062583114549367
# TIMESTEP 221 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.7066193 / Loss  0.9569309949874878
# fps: 12.81141642332645
# TIMESTEP 222 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.571985 / Loss  0.4258328080177307
# fps: 12.81141642332645
# TIMESTEP 223 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.1038265 / Loss  0.5404075384140015
# fps: 12.894084952150243
# TIMESTEP 224 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.9745407 / Loss  0.4052772521972656
# fps: 12.894045313412647
# TIMESTEP 225 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.661428 / Loss  0.3856689929962158
# fps: 12.569387339222995
# TIMESTEP 226 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.7312355 / Loss  0.7608124017715454
# fps: 12.97810837822534
# TIMESTEP 227 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.836841 / Loss  0.8245919942855835
# fps: 12.811455555657371
# TIMESTEP 228 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.26786 / Loss  0.37284737825393677
# fps: 10.518788997451999
# TIMESTEP 229 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.943236 / Loss  0.8297269940376282
# fps: 12.977827284260032
# TIMESTEP 230 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.762299 / Loss  0.8314765095710754
# fps: 10.68756800281312
# TIMESTEP 231 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.329037 / Loss  0.2512621283531189
# fps: 10.301922198370086
# TIMESTEP 232 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.512183 / Loss  0.5625231862068176
# fps: 11.165219428309792
# TIMESTEP 233 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.985998 / Loss  0.13546214997768402
# fps: 12.413627363642014
# TIMESTEP 234 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.270131 / Loss  0.18819200992584229
# fps: 12.894045313412647
# TIMESTEP 235 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.183982 / Loss  0.38232696056365967
# fps: 10.74506528806421
# TIMESTEP 236 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.004084 / Loss  0.5247257947921753
# fps: 10.803128919842678
# TIMESTEP 237 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.439919 / Loss  0.4212716221809387
# fps: 15.373718491476158
# TIMESTEP 238 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.169209 / Loss  0.28213512897491455
# fps: 16.937102245194637
# TIMESTEP 239 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  12.557558 / Loss  0.3912315368652344
# fps: 15.9886555102352
# TIMESTEP 240 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  13.186414 / Loss  0.2264951765537262
# fps: 12.112533860077741
# TIMESTEP 241 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.661386 / Loss  0.21991951763629913
# fps: 9.51706548918346
# TIMESTEP 242 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.977392 / Loss  0.39509207010269165
# fps: 9.125868678824906
# TIMESTEP 243 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.865095 / Loss  0.09123548865318298
# fps: 10.518841757326793
# TIMESTEP 244 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.644906 / Loss  0.28276631236076355
# fps: 11.042087998588906
# TIMESTEP 245 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.528515 / Loss  0.5046579837799072
# fps: 12.33691393611389
# TIMESTEP 246 / STATE explore / EPSILON 0 / ACTION 0 / REWARD -1 / Q_MAX  10.599122 / Loss  0.2717262804508209
# fps: 11.041971720490404
# TIMESTEP 247 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.0029545 / Loss  0.361178994178772
# fps: 10.574533206266608
# TIMESTEP 248 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.028451 / Loss  0.5135635137557983
# fps: 10.46373384026624
# TIMESTEP 249 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.425419 / Loss  0.4502306282520294
# fps: 10.981204493746613
# TIMESTEP 250 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.228088 / Loss  0.2990589141845703
# fps: 10.40927783113573
# TIMESTEP 251 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  13.599858 / Loss  6.009796142578125
# fps: 10.803156745173188
# TIMESTEP 252 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.607871 / Loss  0.4449761211872101
# fps: 10.46373384026624
# TIMESTEP 253 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  13.263718 / Loss  1.9924558401107788
# fps: 10.861935998466905
# TIMESTEP 254 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.552067 / Loss  0.3660726547241211
# fps: 10.5744798862456
# TIMESTEP 255 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.959589 / Loss  0.6015504598617554
# fps: 11.041855444840795
# TIMESTEP 256 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.773453 / Loss  0.37816834449768066
# fps: 10.63079056021777
# TIMESTEP 257 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  13.438851 / Loss  0.2638189494609833
# fps: 12.81141642332645
# TIMESTEP 258 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.817534 / Loss  1.3574399948120117
# fps: 10.518841757326793
# TIMESTEP 259 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.13799 / Loss  0.33874183893203735
# fps: 9.339125516854407
# TIMESTEP 260 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.281019 / Loss  0.7096702456474304
# fps: 12.729801175767177
# TIMESTEP 261 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.564163 / Loss  0.2317500114440918
# fps: 10.518788997451999
# TIMESTEP 262 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.05344 / Loss  0.08119611442089081
# fps: 13.062705160546887
# TIMESTEP 263 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.493824 / Loss  0.14957277476787567
# fps: 10.574453226436738
# TIMESTEP 264 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.116526 / Loss  0.2005714476108551
# fps: 10.463786049296477
# TIMESTEP 265 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.532117 / Loss  0.42898672819137573
# fps: 10.921187755824732
# TIMESTEP 266 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.945001 / Loss  0.1819562017917633
# fps: 10.745120342261332
# TIMESTEP 267 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.0749445 / Loss  0.3308781683444977
# fps: 10.68754076973255
# TIMESTEP 268 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.008649 / Loss  0.1795467883348465
# fps: 10.803156745173188
# TIMESTEP 269 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.909386 / Loss  0.6657708883285522
# fps: 10.355283428797156
# TIMESTEP 270 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.537019 / Loss  0.2004561573266983
# fps: 10.861935998466905
# TIMESTEP 271 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.672122 / Loss  0.11134923994541168
# fps: 10.409251997816051
# TIMESTEP 272 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.287189 / Loss  0.6676126718521118
# fps: 11.041884513523616
# TIMESTEP 273 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.3127894 / Loss  0.4889523983001709
# fps: 9.0844397468497
# TIMESTEP 274 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.9789023 / Loss  0.2542605400085449
# fps: 10.409251997816051
# TIMESTEP 275 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.412652 / Loss  0.3261941373348236
# fps: 10.981233243967829
# TIMESTEP 276 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.570712 / Loss  0.33837518095970154
# fps: 10.574506546188891
# TIMESTEP 277 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.724902 / Loss  0.19327355921268463
# fps: 12.894084952150243
# TIMESTEP 278 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.125093 / Loss  0.2461356818675995
# fps: 12.729685271176667
# TIMESTEP 279 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.963984 / Loss  0.4807719886302948
# fps: 10.745120342261332
# TIMESTEP 280 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.990813 / Loss  0.3710528314113617
# fps: 10.630655839086753
# TIMESTEP 281 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.053303 / Loss  0.36361753940582275
# fps: 12.894164230356578
# TIMESTEP 282 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.8987665 / Loss  0.22670967876911163
# fps: 10.574453226436738
# TIMESTEP 283 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.820278 / Loss  0.16062693297863007
# fps: 10.86182348355954
# TIMESTEP 284 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.809601 / Loss  0.41994455456733704
# fps: 10.518920898131359
# TIMESTEP 285 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.500479 / Loss  0.12828488647937775
# fps: 10.518709858632166
# TIMESTEP 286 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  13.040267 / Loss  0.5367934703826904
# fps: 10.921329941387382
# TIMESTEP 287 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.431192 / Loss  0.3285861611366272
# fps: 10.355130034613353
# TIMESTEP 288 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.751011 / Loss  0.3553847670555115
# fps: 10.981405748456588
# TIMESTEP 289 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.847995 / Loss  0.27341586351394653
# fps: 10.518894517730851
# TIMESTEP 290 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.174204 / Loss  0.32378631830215454
# fps: 10.463759944716234
# TIMESTEP 291 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.768393 / Loss  0.20779502391815186
# fps: 11.10320947913468
# TIMESTEP 292 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  13.130427 / Loss  0.6387814283370972
# fps: 10.518841757326793
# TIMESTEP 293 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.709581 / Loss  0.17354103922843933
# fps: 10.803156745173188
# TIMESTEP 294 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.270675 / Loss  0.13812310993671417
# fps: 12.569462674937817
# TIMESTEP 295 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  15.184409 / Loss  0.1315915286540985
# fps: 10.687758638263174
# TIMESTEP 296 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.776588 / Loss  1.5971388816833496
# fps: 10.68756800281312
# TIMESTEP 297 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.614406 / Loss  0.7566421627998352
# fps: 10.68754076973255
# TIMESTEP 298 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.483394 / Loss  0.3168349266052246
# fps: 10.463786049296477
# TIMESTEP 299 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  13.856468 / Loss  0.1636034995317459
# fps: 10.919993543247227
# TIMESTEP 300 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.502734 / Loss  0.31657829880714417
# fps: 10.409355331864118
# TIMESTEP 301 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.619697 / Loss  0.4048406779766083
# fps: 12.569651018175824
# TIMESTEP 302 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  12.11712 / Loss  0.1488792896270752
# fps: 9.51706548918346
# TIMESTEP 303 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.437066 / Loss  0.16517922282218933
# fps: 10.355130034613353
# TIMESTEP 304 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.360682 / Loss  0.2663516402244568
# fps: 11.042058928834692
# TIMESTEP 305 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.622594 / Loss  0.5674442052841187
# fps: 10.463786049296477
# TIMESTEP 306 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.368134 / Loss  0.6093360781669617
# fps: 10.803240222024753
# TIMESTEP 307 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.9218903 / Loss  0.31628167629241943
# fps: 10.63060195159042
# TIMESTEP 308 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.530731 / Loss  0.17277681827545166
# fps: 10.463786049296477
# TIMESTEP 309 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.433675 / Loss  0.27577027678489685
# fps: 10.981261994339588
# TIMESTEP 310 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.87188 / Loss  0.35282036662101746
# fps: 10.687595236032474
# TIMESTEP 311 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.124549 / Loss  0.34864819049835205
# fps: 10.574293270406478
# TIMESTEP 312 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.216024 / Loss  0.38639014959335327
# fps: 12.730110264994128
# TIMESTEP 313 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.1812096 / Loss  0.2664259076118469
# fps: 10.74506528806421
# TIMESTEP 314 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.465415 / Loss  0.2711031436920166
# fps: 10.630736671355612
# TIMESTEP 315 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.566338 / Loss  0.2842928171157837
# fps: 9.21003236672332
# TIMESTEP 316 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.387199 / Loss  0.1950441598892212
# fps: 10.40927783113573
# TIMESTEP 317 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.032315 / Loss  0.3017289638519287
# fps: 10.92124462960552
# TIMESTEP 318 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.954597 / Loss  0.17128993570804596
# fps: 10.68748630398777
# TIMESTEP 319 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.21253 / Loss  0.11677868664264679
# fps: 10.46347280292976
# TIMESTEP 320 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.811821 / Loss  0.17706862092018127
# fps: 8.882849760684485
# TIMESTEP 321 / STATE explore / EPSILON 0 / ACTION 1 / REWARD -1 / Q_MAX  9.167487 / Loss  0.22349245846271515
# fps: 10.981118243986218
# TIMESTEP 322 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.320355 / Loss  0.4819870591163635
# fps: 10.745092815092251
# TIMESTEP 323 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.36475 / Loss  0.28537362813949585
# fps: 12.729878446666769
# TIMESTEP 324 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.650041 / Loss  0.12366558611392975
# fps: 12.729723905805656
# TIMESTEP 325 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.065101 / Loss  0.16623321175575256
# fps: 13.413402836629944
# TIMESTEP 326 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.665391 / Loss  0.3256814479827881
# fps: 12.261035301271033
# TIMESTEP 327 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.256081 / Loss  0.12803012132644653
# fps: 12.894084952150243
# TIMESTEP 328 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.053451 / Loss  0.8074308633804321
# fps: 12.977947751611296
# TIMESTEP 329 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.258 / Loss  0.49218982458114624
# fps: 12.811377291234587
# TIMESTEP 330 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.678406 / Loss  0.16769829392433167
# fps: 12.649257354826062
# TIMESTEP 331 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.232459 / Loss  0.21271124482154846
# fps: 13.235626942678174
# TIMESTEP 332 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.415526 / Loss  6.217686176300049
# fps: 12.569688687500749
# TIMESTEP 333 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.585981 / Loss  0.22511494159698486
# fps: 12.729839811099714
# TIMESTEP 334 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  13.064024 / Loss  0.19436722993850708
# fps: 12.81129902776802
# TIMESTEP 335 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.9165125 / Loss  0.1201055571436882
# fps: 12.729917082468344
# TIMESTEP 336 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.176131 / Loss  0.29489845037460327
# fps: 12.811338159381776
# TIMESTEP 337 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.666169 / Loss  0.18373966217041016
# fps: 12.97786743979529
# TIMESTEP 338 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.919176 / Loss  0.22975361347198486
# fps: 12.649181059571093
# TIMESTEP 339 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.12441 / Loss  0.3294212818145752
# fps: 12.811455555657371
# TIMESTEP 340 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  14.8923235 / Loss  0.3098410665988922
# fps: 12.97778712897327
# TIMESTEP 341 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.837691 / Loss  0.9639925956726074
# fps: 12.729801175767177
# TIMESTEP 342 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  13.053219 / Loss  0.39041492342948914
# fps: 12.811377291234587
# TIMESTEP 343 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.828434 / Loss  0.2945237159729004
# fps: 16.24874191786341
# TIMESTEP 344 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  13.152536 / Loss  0.29532289505004883
# fps: 12.729685271176667
# TIMESTEP 345 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.626084 / Loss  0.10212615132331848
# fps: 12.89412459113155
# TIMESTEP 346 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.900237 / Loss  4.272151470184326
# fps: 12.569575680203304
# TIMESTEP 347 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  13.8760805 / Loss  1.2709823846817017
# fps: 13.062664478294316
# TIMESTEP 348 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.516448 / Loss  1.003997802734375
# fps: 16.12040617097
# TIMESTEP 349 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  14.300234 / Loss  0.26609155535697937
# fps: 15.736764104468932
# TIMESTEP 350 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  15.721742 / Loss  0.20083561539649963
# fps: 13.062623796295142
# TIMESTEP 351 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.913896 / Loss  0.1195976734161377
# fps: 12.811377291234587
# TIMESTEP 352 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.157969 / Loss  0.14474192261695862
# fps: 10.40927783113573
# TIMESTEP 353 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.2071085 / Loss  0.30537867546081543
# fps: 10.981261994339588
# TIMESTEP 354 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.517147 / Loss  0.29665499925613403
# fps: 12.649219207083531
# TIMESTEP 355 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.72477 / Loss  0.3948681354522705
# fps: 12.729723905805656
# TIMESTEP 356 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.023541 / Loss  0.19209960103034973
# fps: 13.148618147163566
# TIMESTEP 357 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.029416 / Loss  1.3083276748657227
# fps: 12.1100858096481
# TIMESTEP 358 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.52107 / Loss  0.5599740743637085
# fps: 10.862048515705322
# TIMESTEP 359 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.192091 / Loss  0.41295772790908813
# fps: 11.041884513523616
# TIMESTEP 360 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.5710573 / Loss  0.24770253896713257
# fps: 10.68754076973255
# TIMESTEP 361 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.907601 / Loss  0.20114551484584808
# fps: 12.413370189945722
# TIMESTEP 362 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.752304 / Loss  0.29894059896469116
# fps: 13.235919315341699
# TIMESTEP 363 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.300856 / Loss  0.1624717116355896
# fps: 10.518815377323238
# TIMESTEP 364 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.966288 / Loss  0.31162893772125244
# fps: 13.323837266555907
# TIMESTEP 365 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.132059 / Loss  0.27983927726745605
# fps: 12.729723905805656
# TIMESTEP 366 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.041499 / Loss  0.2976447343826294
# fps: 12.811533821036395
# TIMESTEP 367 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.561878 / Loss  0.1733541041612625
# fps: 12.33691393611389
# TIMESTEP 368 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.461842 / Loss  1.9127938747406006
# fps: 13.235501644062127
# TIMESTEP 369 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.12634 / Loss  0.14545898139476776
# fps: 12.977907595579044
# TIMESTEP 370 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.549581 / Loss  0.44233208894729614
# fps: 15.492858066303445
# TIMESTEP 371 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  11.626166 / Loss  0.362354040145874
# fps: 13.148659366565202
# TIMESTEP 372 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.685076 / Loss  1.8644341230392456
# fps: 12.97786743979529
# TIMESTEP 373 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.816097 / Loss  0.17081846296787262
# fps: 14.588071620361998
# TIMESTEP 374 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.832108 / Loss  0.13587632775306702
# fps: 11.420499317923765
# TIMESTEP 375 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.399349 / Loss  0.2552620470523834
# fps: 15.736764104468932
# TIMESTEP 376 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  11.234822 / Loss  0.1805325746536255
# fps: 12.89412459113155
# ...
# fps: 10.803240222024753
# TIMESTEP 10604 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.174075 / Loss  0.7481816411018372
# fps: 10.687595236032474
# TIMESTEP 10605 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  2.837169 / Loss  0.24303165078163147
# fps: 10.46381215400697
# TIMESTEP 10606 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  5.1527867 / Loss  0.4545719027519226
# fps: 9.339125516854407
# TIMESTEP 10607 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.368836 / Loss  0.3314346671104431
# fps: 9.167797440022383
# TIMESTEP 10608 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.484377 / Loss  0.4154631495475769
# fps: 9.210072814468033
# TIMESTEP 10609 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.237512 / Loss  0.2092851847410202
# fps: 9.002603568584608
# TIMESTEP 10610 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.680182 / Loss  0.33151841163635254
# fps: 10.921187755824732
# TIMESTEP 10611 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  5.446022 / Loss  0.23095665872097015
# fps: 8.843257557548693
# TIMESTEP 10612 / STATE explore / EPSILON 0 / ACTION 1 / REWARD -1 / Q_MAX  8.937032 / Loss  0.294380247592926
# fps: 9.427266515625561
# TIMESTEP 10613 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  3.45654 / Loss  0.14360195398330688
# fps: 10.74506528806421
# TIMESTEP 10614 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.7615643 / Loss  0.542370080947876
# fps: 9.042020574818698
# TIMESTEP 10615 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.2724414 / Loss  0.37931323051452637
# fps: 9.21146847925154
# TIMESTEP 10616 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.633131 / Loss  0.3394767642021179
# fps: 10.574506546188891
# TIMESTEP 10617 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.271665 / Loss  0.2963095009326935
# fps: 9.295721707061931
# TIMESTEP 10618 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.003127 / Loss  0.26533252000808716
# fps: 9.04334626994394
# TIMESTEP 10619 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.366479 / Loss  0.1267271786928177
# fps: 8.026423658819432
# TIMESTEP 10620 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.24422 / Loss  0.3195192515850067
# fps: 9.210012142984187
# TIMESTEP 10621 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.0723667 / Loss  0.13323788344860077
# fps: 9.0433267716111
# TIMESTEP 10622 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  3.4030132 / Loss  0.2286781370639801
# fps: 9.16781747879249
# TIMESTEP 10623 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.3412185 / Loss  0.45267096161842346
# fps: 9.125948102923834
# TIMESTEP 10624 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  2.3343701 / Loss  0.2967212498188019
# fps: 9.12590839070156
# TIMESTEP 10625 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  -1.0996071 / Loss  0.29434657096862793
# fps: 9.12590839070156
# TIMESTEP 10626 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.543082 / Loss  0.7637645602226257
# fps: 9.427287704731958
# TIMESTEP 10627 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.017048 / Loss  0.42162302136421204
# fps: 8.765727111804033
# TIMESTEP 10628 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.5204577 / Loss  0.11414163559675217
# fps: 8.292825861301962
# TIMESTEP 10629 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.491679 / Loss  0.21429450809955597
# fps: 10.301871592081348
# TIMESTEP 10630 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.2790847 / Loss  0.10550110787153244
# fps: 9.383083486388356
# TIMESTEP 10631 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.489625 / Loss  0.134375661611557
# fps: 10.630817504853729
# TIMESTEP 10632 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  3.5923731 / Loss  0.256940096616745
# fps: 10.630655839086753
# TIMESTEP 10633 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  5.415289 / Loss  0.31964853405952454
# fps: 10.687622469390615
# TIMESTEP 10634 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.457999 / Loss  0.3875640630722046
# fps: 9.21003236672332
# TIMESTEP 10635 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.6856356 / Loss  2.534313678741455
# fps: 9.043365768360863
# TIMESTEP 10636 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.987645 / Loss  0.3230424225330353
# fps: 9.16781747879249
# TIMESTEP 10637 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  3.7381682 / Loss  0.31337422132492065
# fps: 10.803101094655505
# TIMESTEP 10638 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  7.830076 / Loss  0.2679781913757324
# fps: 9.084479098982023
# TIMESTEP 10639 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.747476 / Loss  0.4335906505584717
# fps: 10.463759944716234
# TIMESTEP 10640 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.308744 / Loss  0.291642963886261
# fps: 10.921130882636296
# TIMESTEP 10641 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  6.1054697 / Loss  0.6773998737335205
# fps: 9.209991919333872
# TIMESTEP 10642 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.117478 / Loss  0.18266561627388
# fps: 9.209951472299686
# TIMESTEP 10643 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.1803575 / Loss  0.20333707332611084
# fps: 9.043502259633629
# TIMESTEP 10644 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.207972 / Loss  0.46868884563446045
# fps: 10.630709727129409
# TIMESTEP 10645 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  5.059223 / Loss  0.39830514788627625
# fps: 9.125888534720032
# TIMESTEP 10646 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.375869 / Loss  0.24297015368938446
# fps: 10.302048716267166
# TIMESTEP 10647 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.343216 / Loss  0.13730719685554504
# fps: 9.471889001300767
# TIMESTEP 10648 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.265021 / Loss  0.3508158028125763
# fps: 10.74501023443124
# TIMESTEP 10649 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.259972 / Loss  0.6110091209411621
# fps: 9.210072814468033
# TIMESTEP 10650 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.92197 / Loss  0.1327207088470459
# fps: 8.9622454844796
# TIMESTEP 10651 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.507721 / Loss  0.17342060804367065
# fps: 9.25265823678382
# TIMESTEP 10652 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.684368 / Loss  0.33785584568977356
# fps: 10.981233243967829
# TIMESTEP 10653 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  5.121502 / Loss  0.19950860738754272
# fps: 9.043385266861867
# TIMESTEP 10654 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  5.715042 / Loss  0.17962898313999176
# fps: 9.25265823678382
# TIMESTEP 10655 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.6077766 / Loss  0.3943873643875122
# fps: 9.084400395058307
# TIMESTEP 10656 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.926164 / Loss  0.3868749737739563
# fps: 10.63079056021777
# TIMESTEP 10657 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  5.525635 / Loss  0.09463724493980408
# fps: 10.62895864534947
# TIMESTEP 10658 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  3.9469206 / Loss  0.03828626126050949
# fps: 10.80496569916766
# TIMESTEP 10659 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.537683 / Loss  0.2884983420372009
# fps: 9.167777401339876
# TIMESTEP 10660 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.132072 / Loss  0.12569746375083923
# fps: 9.002642214910162
# TIMESTEP 10661 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.016797 / Loss  0.3441618084907532
# fps: 9.210052590551268
# TIMESTEP 10662 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.5309725 / Loss  0.2268412858247757
# fps: 8.922171712766886
# TIMESTEP 10663 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.833826 / Loss  0.3124932050704956
# fps: 9.383041504757175
# TIMESTEP 10664 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.90154 / Loss  0.2734207510948181
# fps: 10.249083049675372
# TIMESTEP 10665 / STATE explore / EPSILON 0 / ACTION 0 / REWARD -1 / Q_MAX  5.26882 / Loss  0.2673851549625397
# fps: 9.608635690951493
# TIMESTEP 10666 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.24201 / Loss  0.443278968334198
# fps: 9.084459422873245
# TIMESTEP 10667 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.184121 / Loss  0.7339016795158386
# fps: 10.630655839086753
# TIMESTEP 10668 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  5.916818 / Loss  0.5439096093177795
# fps: 9.210012142984187
# TIMESTEP 10669 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.372382 / Loss  0.3843003511428833
# fps: 9.167797440022383
# TIMESTEP 10670 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.523671 / Loss  0.2227478325366974
# fps: 10.518815377323238
# TIMESTEP 10671 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.044412 / Loss  0.21623171865940094
# fps: 9.25267864824501
# TIMESTEP 10672 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.180216 / Loss  0.13468538224697113
# fps: 9.210072814468033
# TIMESTEP 10673 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.4461718 / Loss  0.5024824738502502
# fps: 9.084420070911387
# TIMESTEP 10674 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.318903 / Loss  0.5078063011169434
# fps: 9.084459422873245
# TIMESTEP 10675 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.041342 / Loss  0.18903830647468567
# fps: 9.167777401339876
# TIMESTEP 10676 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.015881 / Loss  0.6537599563598633
# fps: 9.043365768360863
# TIMESTEP 10677 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.621167 / Loss  0.2874203324317932
# fps: 10.745037761177207
# TIMESTEP 10678 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.583932 / Loss  0.21669691801071167
# fps: 10.861795355196918
# TIMESTEP 10679 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.885566 / Loss  0.8523896932601929
# fps: 9.084459422873245
# TIMESTEP 10680 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.452043 / Loss  0.15260997414588928
# fps: 9.125928246769494
# TIMESTEP 10681 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  12.008869 / Loss  0.5271565318107605
# fps: 9.084498775176035
# TIMESTEP 10682 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.96698 / Loss  0.27523234486579895
# fps: 9.339208696368571
# TIMESTEP 10683 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.838549 / Loss  0.2092103511095047
# fps: 8.026377579822606
# TIMESTEP 10684 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.607897 / Loss  0.3783475160598755
# fps: 9.084459422873245
# TIMESTEP 10685 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.286558 / Loss  0.3715481758117676
# fps: 8.962207184203384
# TIMESTEP 10686 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.730423 / Loss  0.1495482474565506
# fps: 9.339187901351123
# TIMESTEP 10687 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.9689217 / Loss  0.238486185669899
# fps: 9.084479098982023
# TIMESTEP 10688 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.48095 / Loss  0.3509654402732849
# fps: 9.25265823678382
# TIMESTEP 10689 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.566008 / Loss  0.29450392723083496
# fps: 9.04334626994394
# TIMESTEP 10690 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.014962 / Loss  0.07641276717185974
# fps: 9.295742308962405
# TIMESTEP 10691 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.760826 / Loss  0.4208070933818817
# fps: 8.921773164298477
# TIMESTEP 10692 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.934551 / Loss  0.29702046513557434
# fps: 9.253127723176368
# TIMESTEP 10693 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.6612835 / Loss  0.6297741532325745
# fps: 8.058840256696
# TIMESTEP 10694 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.112007 / Loss  0.18170706927776337
# fps: 8.058778320882904
# TIMESTEP 10695 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.573934 / Loss  0.23430564999580383
# fps: 9.0433267716111
# TIMESTEP 10696 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.756456 / Loss  0.14970044791698456
# fps: 9.295721707061931
# TIMESTEP 10697 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  11.112738 / Loss  0.43164539337158203
# fps: 10.463786049296477
# TIMESTEP 10698 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  10.990745 / Loss  0.2852196991443634
# fps: 10.80307326961167
# TIMESTEP 10699 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  6.2234416 / Loss  0.11217145621776581
# fps: 9.16775736274497
# TIMESTEP 10700 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.3042345 / Loss  0.4384864568710327
# fps: 9.210113262568017
# TIMESTEP 10701 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.32373 / Loss  0.5029566884040833
# fps: 10.46373384026624
# TIMESTEP 10702 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  4.7212057 / Loss  0.45763397216796875
# fps: 10.687595236032474
# TIMESTEP 10703 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  9.096056 / Loss  0.2641206383705139
# fps: 9.084420070911387
# TIMESTEP 10704 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.351527 / Loss  0.4704956114292145
# fps: 10.68756800281312
# TIMESTEP 10705 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  11.148199 / Loss  0.1084766685962677
# fps: 9.295804115211745
# TIMESTEP 10706 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.483666 / Loss  0.3400057852268219
# fps: 9.002584245546254
# TIMESTEP 10707 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.794567 / Loss  0.6008443236351013
# fps: 9.125868678824906
# TIMESTEP 10708 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  7.0460153 / Loss  0.36703240871429443
# fps: 10.921187755824732
# TIMESTEP 10709 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  8.733955 / Loss  0.25392448902130127
# fps: 9.94313809624279
# TIMESTEP 10710 / STATE explore / EPSILON 0 / ACTION 0 / REWARD -1 / Q_MAX  6.650728 / Loss  0.22147053480148315
# fps: 8.360916644074825
# TIMESTEP 10711 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.222417 / Loss  0.33078768849372864
# fps: 9.3401029697326
# TIMESTEP 10712 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  10.240317 / Loss  0.30792051553726196
# fps: 10.74506528806421
# TIMESTEP 10713 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  11.073266 / Loss  0.2758011817932129
# fps: 10.574506546188891
# TIMESTEP 10714 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  5.3996887 / Loss  0.18151968717575073
# fps: 9.001850031549262
# TIMESTEP 10715 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  4.7578344 / Loss  0.4288857579231262
# fps: 6.489305181011262
# TIMESTEP 10716 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.4930935 / Loss  0.16255277395248413
# fps: 10.68756800281312
# TIMESTEP 10717 / STATE explore / EPSILON 0 / ACTION 0 / REWARD 0.1 / Q_MAX  6.2594404 / Loss  0.1414143592119217
# fps: 9.125928246769494
# TIMESTEP 10718 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  8.593788 / Loss  0.2564256489276886
# fps: 8.9622454844796
# TIMESTEP 10719 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  6.3576145 / Loss  0.24803459644317627
# fps: 9.252699059796253
# TIMESTEP 10720 / STATE explore / EPSILON 0 / ACTION 1 / REWARD 0.1 / Q_MAX  9.550566 / Loss  0.4030003547668457
# fps: 9.210052590551268
